# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %%
df=pd.read_csv('test1.csv',encoding = 'unicode_escape')

# %%
df.head()
# Out:
#                                      Qualification           Experience  \
# 0                                             MBBS  35 years experience
# 1       MBBS, Diploma in Otorhinolaryngology (DLO)  31 years experience
# 2                                       MBBS, DDVL  40 years experience
# 3                                             BAMS   0 years experience
# 4  BDS, MDS - Conservative Dentistry & Endodontics  16 years experience
#
#   Rating                        Place           Profile  \
# 0    NaN       Ghatkopar East, Mumbai  General Medicine
# 1    NaN  West Marredpally, Hyderabad    ENT Specialist
# 2    70%            KK Nagar, Chennai    Dermatologists
# 3    NaN       New Ashok Nagar, Delhi          Ayurveda
# 4   100%    Kanakpura Road, Bangalore           Dentist
#
#                                   Miscellaneous_Info
# 0                                                NaN
# 1                                                NaN
# ...

# %%
df['Qualification'].value_counts
# Out:
# <bound method IndexOpsMixin.value_counts of 0                                                    MBBS
# 1              MBBS, Diploma in Otorhinolaryngology (DLO)
# 2                                              MBBS, DDVL
# 3                                                    BAMS
# 4         BDS, MDS - Conservative Dentistry & Endodontics
# 5                                                BDS, MDS
# 6              MBBS, Diploma in Otorhinolaryngology (DLO)
# 7                                  BDS, MDS - Pedodontics
# 8       MD - Ayurveda Medicine, BAMS, Yoga Teachers Tr...
# 9                                                    BHMS
# 10                                                    BDS
# 11                                MBBS, FCD - Diabetology
# 12                                              MBBS, DDV
# 13                                 MBBS, MD - Dermatology
# 14                                               MS - ENT
# ...

# %%
df.head()
# Out:
#                                      Qualification           Experience  \
# 0                                             MBBS  35 years experience
# 1       MBBS, Diploma in Otorhinolaryngology (DLO)  31 years experience
# 2                                       MBBS, DDVL  40 years experience
# 3                                             BAMS   0 years experience
# 4  BDS, MDS - Conservative Dentistry & Endodontics  16 years experience
#
#   Rating                        Place           Profile  \
# 0    NaN       Ghatkopar East, Mumbai  General Medicine
# 1    NaN  West Marredpally, Hyderabad    ENT Specialist
# 2    70%            KK Nagar, Chennai    Dermatologists
# 3    NaN       New Ashok Nagar, Delhi          Ayurveda
# 4   100%    Kanakpura Road, Bangalore           Dentist
#
#                                   Miscellaneous_Info
# 0                                                NaN
# 1                                                NaN
# ...

# %%
qual=df['Qualification'].str.split(',')

# %%
qualifications=[]
range=np.arange(0,len(qual))
for m in range:
    qualifications.append(len(qual[m]))

# %%
max(qualifications)
# Out:
# 17

# %%
df['qual 1']=df['Qualification'].str.split(',').str[0]
df['qual 2']=df['Qualification'].str.split(',').str[1]
df['qual 3']=df['Qualification'].str.split(',').str[2]
df['qual 4']=df['Qualification'].str.split(',').str[3]
df['qual 5']=df['Qualification'].str.split(',').str[4]
df['qual 6']=df['Qualification'].str.split(',').str[5]
df['qual 7']=df['Qualification'].str.split(',').str[6]
df['qual 8']=df['Qualification'].str.split(',').str[7]
df['qual 9']=df['Qualification'].str.split(',').str[8]
df['qual 10']=df['Qualification'].str.split(',').str[9]
df['qual 11']=df['Qualification'].str.split(',').str[10]
df['qual 12']=df['Qualification'].str.split(',').str[11]
df['qual 13']=df['Qualification'].str.split(',').str[12]
df['qual 14']=df['Qualification'].str.split(',').str[13]
df['qual 15']=df['Qualification'].str.split(',').str[14]
df['qual 16']=df['Qualification'].str.split(',').str[15]
df['qual 17']=df['Qualification'].str.split(',').str[16]

# %%
df.head()
# Out:
#                                      Qualification           Experience  \
# 0                                             MBBS  35 years experience
# 1       MBBS, Diploma in Otorhinolaryngology (DLO)  31 years experience
# 2                                       MBBS, DDVL  40 years experience
# 3                                             BAMS   0 years experience
# 4  BDS, MDS - Conservative Dentistry & Endodontics  16 years experience
#
#   Rating                        Place           Profile  \
# 0    NaN       Ghatkopar East, Mumbai  General Medicine
# 1    NaN  West Marredpally, Hyderabad    ENT Specialist
# 2    70%            KK Nagar, Chennai    Dermatologists
# 3    NaN       New Ashok Nagar, Delhi          Ayurveda
# 4   100%    Kanakpura Road, Bangalore           Dentist
#
#                                   Miscellaneous_Info qual 1  \
# 0                                                NaN   MBBS
# 1                                                NaN   MBBS
# ...

# %%
df['exp']=df['Experience'].str.split(' ').str[0]

# %%
df['rating']=df['Rating'].str.split('%').str[0]

# %%
df['city']=df['Place'].str.split(',').str[1]

# %%
df['Location']=df['Place'].str.split(',').str[0]

# %%
df.Profile.value_counts()
# Out:
# General Medicine    444
# Dentist             441
# Dermatologists      339
# Homeopath           277
# Ayurveda            251
# ENT Specialist      235
# Name: Profile, dtype: int64

# %%
df.head()
# Out:
#                                      Qualification           Experience  \
# 0                                             MBBS  35 years experience
# 1       MBBS, Diploma in Otorhinolaryngology (DLO)  31 years experience
# 2                                       MBBS, DDVL  40 years experience
# 3                                             BAMS   0 years experience
# 4  BDS, MDS - Conservative Dentistry & Endodontics  16 years experience
#
#   Rating                        Place           Profile  \
# 0    NaN       Ghatkopar East, Mumbai  General Medicine
# 1    NaN  West Marredpally, Hyderabad    ENT Specialist
# 2    70%            KK Nagar, Chennai    Dermatologists
# 3    NaN       New Ashok Nagar, Delhi          Ayurveda
# 4   100%    Kanakpura Road, Bangalore           Dentist
#
#                                   Miscellaneous_Info qual 1  \
# 0                                                NaN   MBBS
# 1                                                NaN   MBBS
# ...

# %%
df.isnull().sum()/len(df)
# Out:
# Qualification         0.000000
# Experience            0.000000
# Rating                0.548566
# Place                 0.003020
# Profile               0.000000
# Miscellaneous_Info    0.419728
# qual 1                0.000000
# qual 2                0.306492
# qual 3                0.753900
# qual 4                0.938098
# qual 5                0.981882
# qual 6                0.995974
# qual 7                0.998490
# qual 8                0.998993
# qual 9                0.998993
# qual 10               0.999497
# qual 11               0.999497
# qual 12               0.999497
# qual 13               0.999497
# qual 14               0.999497
# qual 15               0.999497
# qual 16               0.999497
# qual 17               0.999497
# exp                   0.000000
# rating                0.548566
# city                  0.003020
# Location              0.003020
# dtype: float64

# %%
df.shape
# Out:
# (1987, 27)

# %% [markdown]
# # we will impute the missing values of 'Rating' column and drop the 'Miscellaneous_Info' as it has over 40% missing data.

# %%
df.drop('Miscellaneous_Info',inplace=True,axis=1)

# %%
df.columns
# Out:
# Index(['Qualification', 'Experience', 'Rating', 'Place', 'Profile', 'qual 1',
#        'qual 2', 'qual 3', 'qual 4', 'qual 5', 'qual 6', 'qual 7', 'qual 8',
#        'qual 9', 'qual 10', 'qual 11', 'qual 12', 'qual 13', 'qual 14',
#        'qual 15', 'qual 16', 'qual 17', 'exp', 'rating', 'city', 'Location'],
#       dtype='object')

# %%
from sklearn.impute import SimpleImputer

# %%
si=SimpleImputer(strategy='mean')
sim=SimpleImputer(strategy='most_frequent')

# %%
df.isnull().sum()
# Out:
# Qualification       0
# Experience          0
# Rating           1090
# Place               6
# Profile             0
# qual 1              0
# qual 2            609
# qual 3           1498
# qual 4           1864
# qual 5           1951
# qual 6           1979
# qual 7           1984
# qual 8           1985
# qual 9           1985
# qual 10          1986
# qual 11          1986
# qual 12          1986
# qual 13          1986
# qual 14          1986
# qual 15          1986
# qual 16          1986
# qual 17          1986
# exp                 0
# rating           1090
# city                6
# Location            6
# dtype: int64

# %%
df['rating']=si.fit_transform(df['rating'].values.reshape(-1,1))
df['Place']=sim.fit_transform(df['Place'].values.reshape(-1,1))
df['Location']=sim.fit_transform(df['Location'].values.reshape(-1,1))

# %%
df.isnull().sum()
# Out:
# Qualification       0
# Experience          0
# Rating           1090
# Place               0
# Profile             0
# qual 1              0
# qual 2            609
# qual 3           1498
# qual 4           1864
# qual 5           1951
# qual 6           1979
# qual 7           1984
# qual 8           1985
# qual 9           1985
# qual 10          1986
# qual 11          1986
# qual 12          1986
# qual 13          1986
# qual 14          1986
# qual 15          1986
# qual 16          1986
# qual 17          1986
# exp                 0
# rating              0
# city                6
# Location            0
# dtype: int64

# %%
df.fillna('na',inplace=True)

# %%
df.head()
# Out:
#                                      Qualification           Experience  \
# 0                                             MBBS  35 years experience
# 1       MBBS, Diploma in Otorhinolaryngology (DLO)  31 years experience
# 2                                       MBBS, DDVL  40 years experience
# 3                                             BAMS   0 years experience
# 4  BDS, MDS - Conservative Dentistry & Endodontics  16 years experience
#
#   Rating                        Place           Profile qual 1  \
# 0     na       Ghatkopar East, Mumbai  General Medicine   MBBS
# 1     na  West Marredpally, Hyderabad    ENT Specialist   MBBS
# 2    70%            KK Nagar, Chennai    Dermatologists   MBBS
# 3     na       New Ashok Nagar, Delhi          Ayurveda   BAMS
# 4   100%    Kanakpura Road, Bangalore           Dentist    BDS
#
#                                         qual 2 qual 3 qual 4 qual 5  ...  \
# 0                                           na     na     na     na  ...
# ...

# %%
drop=['Qualification','Experience','Rating','Place']
df.drop(drop,inplace=True,axis=1)

# %%
rfr=RandomForestRegressor()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-30-051f00df4b24> in <module>
# ----> 1 rfr=RandomForestRegressor()
#
# NameError: name 'RandomForestRegressor' is not defined
