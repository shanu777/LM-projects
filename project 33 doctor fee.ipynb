# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %%
df=pd.read_csv('doctor.csv',encoding = 'unicode_escape')

# %%
df.head()
# Out:
#                     Qualification           Experience Rating  \
# 0           BHMS, MD - Homeopathy  24 years experience   100%
# 1    BAMS, MD - Ayurveda Medicine  12 years experience    98%
# 2  MBBS, MS - Otorhinolaryngology   9 years experience    NaN
# 3             BSc - Zoology, BAMS  12 years experience    NaN
# 4                            BAMS  20 years experience   100%
#
#                           Place         Profile  \
# 0           Kakkanad, Ernakulam       Homeopath
# 1         Whitefield, Bangalore        Ayurveda
# 2    Mathikere - BEL, Bangalore  ENT Specialist
# 3  Bannerghatta Road, Bangalore        Ayurveda
# 4         Keelkattalai, Chennai        Ayurveda
#
#                                   Miscellaneous_Info  Fees
# 0               100% 16 Feedback Kakkanad, Ernakulam   100
# 1              98% 76 Feedback Whitefield, Bangalore   350
# 2                                                NaN   300
# 3  Bannerghatta Road, Bangalore ?250 Available on...   250
# 4              100% 4 Feedback Keelkattalai, Chennai   250

# %%
df['Qualification'].value_counts
# Out:
# <bound method IndexOpsMixin.value_counts of 0                                   BHMS, MD - Homeopathy
# 1                            BAMS, MD - Ayurveda Medicine
# 2                          MBBS, MS - Otorhinolaryngology
# 3                                     BSc - Zoology, BAMS
# 4                                                    BAMS
# 5                                                    BAMS
# 6                                                    BHMS
# 7                                                     BDS
# 8                             MBBS, MD - General Medicine
# 9                                                BSc, BDS
# 10                                    MBBS, MS, DNB - ENT
# 11                                                   BAMS
# 12                                               BDS, MDS
# 13                BDS, MDS - Oral & Maxillofacial Surgery
# 14      MBBS, Diploma in Otorhinolaryngology (DLO), DN...
# 15                            MBBS, MD - General Medicine
# 16             MBBS, Diploma in Otorhinolaryngology (DLO)
# 17                                   MBBS, MF- Homeopathy
# 18                                         MBBS, MS - ENT
# 19                                                   MBBS
# 20                                          MDS, DNB, BDS
# 21                                        MBBS, DNB - ENT
# 22                                                   MBBS
# 23      MBBS, Fellowship of College of General Practic...
# 24                                             MBBS, DDVL
# 25                                                    BDS
# 26                                      MBBS, IBCLC (USA)
# 27      MBBS, MD - General Medicine, Post Graduate Dip...
# 28                                               BDS, MDS
# 29                           Diploma in Dermatology, MBBS
#                               ...
# 5931    MBBS, MRCP (UK), Post Graduate Diploma in Diab...
# 5932                                                  BDS
# 5933                                BHMS, MD - Homeopathy
# 5934                                                 BHMS
# 5935      MDS - Periodontology and Oral Implantology, BDS
# 5936    MD - Homeopathy, LCEH, Diploma in Preventive &...
# 5937                                            BHMS, MSc
# 5938                                                 MBBS
# 5939                                BHMS, MD - Pediatrics
# 5940                               MBBS, MD - Dermatology
# 5941                                                 BHMS
# 5942                          MBBS, MD - General Medicine
# 5943                                                  BDS
# 5944                                             MS - ENT
# 5945    BDS, FDS Endodontics, Certified in Advanced Or...
# 5946                                                  BDS
# 5947                                                 BHMS
# 5948                                                 BAMS
# 5949                                                 BHMS
# 5950    MD - Dermatology , Venereology & Leprosy, MBBS...
# 5951                BDS, certification in smile designing
# 5952                                                 MBBS
# 5953    MD - Homeopathy, Post Graduate Diploma in Heal...
# 5954                                                 BHMS
# 5955                                      MD - Homeopathy
# 5956                                       MBBS, MS - ENT
# 5957                                                 MBBS
# 5958                                                 MBBS
# 5959                          MBBS, MD - General Medicine
# 5960                              BDS, MDS - Orthodontics
# Name: Qualification, Length: 5961, dtype: object>

# %%
df.head()
# Out:
#                     Qualification           Experience Rating  \
# 0           BHMS, MD - Homeopathy  24 years experience   100%
# 1    BAMS, MD - Ayurveda Medicine  12 years experience    98%
# 2  MBBS, MS - Otorhinolaryngology   9 years experience    NaN
# 3             BSc - Zoology, BAMS  12 years experience    NaN
# 4                            BAMS  20 years experience   100%
#
#                           Place         Profile  \
# 0           Kakkanad, Ernakulam       Homeopath
# 1         Whitefield, Bangalore        Ayurveda
# 2    Mathikere - BEL, Bangalore  ENT Specialist
# 3  Bannerghatta Road, Bangalore        Ayurveda
# 4         Keelkattalai, Chennai        Ayurveda
#
#                                   Miscellaneous_Info  Fees
# 0               100% 16 Feedback Kakkanad, Ernakulam   100
# 1              98% 76 Feedback Whitefield, Bangalore   350
# 2                                                NaN   300
# 3  Bannerghatta Road, Bangalore ?250 Available on...   250
# 4              100% 4 Feedback Keelkattalai, Chennai   250

# %%
qual=df['Qualification'].str.split(',')

# %%
qualifications=[]
range=np.arange(0,len(qual))
for m in range:
    qualifications.append(len(qual[m]))

# %%
max(qualifications)
# Out:
# 10

# %%
df['qual 1']=df['Qualification'].str.split(',').str[0]
df['qual 2']=df['Qualification'].str.split(',').str[1]
df['qual 3']=df['Qualification'].str.split(',').str[2]
df['qual 4']=df['Qualification'].str.split(',').str[3]
df['qual 5']=df['Qualification'].str.split(',').str[4]
df['qual 6']=df['Qualification'].str.split(',').str[5]
df['qual 7']=df['Qualification'].str.split(',').str[6]
df['qual 8']=df['Qualification'].str.split(',').str[7]
df['qual 9']=df['Qualification'].str.split(',').str[8]
df['qual 10']=df['Qualification'].str.split(',').str[9]

# %%
df.head()
# Out:
#                     Qualification           Experience Rating  \
# 0           BHMS, MD - Homeopathy  24 years experience   100%
# 1    BAMS, MD - Ayurveda Medicine  12 years experience    98%
# 2  MBBS, MS - Otorhinolaryngology   9 years experience    NaN
# 3             BSc - Zoology, BAMS  12 years experience    NaN
# 4                            BAMS  20 years experience   100%
#
#                           Place         Profile  \
# 0           Kakkanad, Ernakulam       Homeopath
# 1         Whitefield, Bangalore        Ayurveda
# 2    Mathikere - BEL, Bangalore  ENT Specialist
# 3  Bannerghatta Road, Bangalore        Ayurveda
# 4         Keelkattalai, Chennai        Ayurveda
#
#                                   Miscellaneous_Info  Fees         qual 1  \
# 0               100% 16 Feedback Kakkanad, Ernakulam   100           BHMS
# 1              98% 76 Feedback Whitefield, Bangalore   350           BAMS
# 2                                                NaN   300           MBBS
# 3  Bannerghatta Road, Bangalore ?250 Available on...   250  BSc - Zoology
# 4              100% 4 Feedback Keelkattalai, Chennai   250           BAMS
#
#                       qual 2 qual 3 qual 4 qual 5 qual 6 qual 7 qual 8 qual 9  \
# 0            MD - Homeopathy    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 1     MD - Ayurveda Medicine    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 2   MS - Otorhinolaryngology    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 3                       BAMS    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 4                        NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
#
#   qual 10
# 0     NaN
# 1     NaN
# 2     NaN
# 3     NaN
# 4     NaN

# %%
df['exp']=df['Experience'].str.split(' ').str[0]

# %%
df['rating']=df['Rating'].str.split('%').str[0]

# %%
df['city']=df['Place'].str.split(',').str[1]

# %%
df['Location']=df['Place'].str.split(',').str[0]

# %%
df.Profile.value_counts()
# Out:
# Dentist             1397
# General Medicine    1173
# Dermatologists      1034
# Homeopath            843
# Ayurveda             786
# ENT Specialist       728
# Name: Profile, dtype: int64

# %%
df.head()
# Out:
#                     Qualification           Experience Rating  \
# 0           BHMS, MD - Homeopathy  24 years experience   100%
# 1    BAMS, MD - Ayurveda Medicine  12 years experience    98%
# 2  MBBS, MS - Otorhinolaryngology   9 years experience    NaN
# 3             BSc - Zoology, BAMS  12 years experience    NaN
# 4                            BAMS  20 years experience   100%
#
#                           Place         Profile  \
# 0           Kakkanad, Ernakulam       Homeopath
# 1         Whitefield, Bangalore        Ayurveda
# 2    Mathikere - BEL, Bangalore  ENT Specialist
# 3  Bannerghatta Road, Bangalore        Ayurveda
# 4         Keelkattalai, Chennai        Ayurveda
#
#                                   Miscellaneous_Info  Fees         qual 1  \
# 0               100% 16 Feedback Kakkanad, Ernakulam   100           BHMS
# 1              98% 76 Feedback Whitefield, Bangalore   350           BAMS
# 2                                                NaN   300           MBBS
# 3  Bannerghatta Road, Bangalore ?250 Available on...   250  BSc - Zoology
# 4              100% 4 Feedback Keelkattalai, Chennai   250           BAMS
#
#                       qual 2 qual 3  ... qual 5 qual 6 qual 7 qual 8 qual 9  \
# 0            MD - Homeopathy    NaN  ...    NaN    NaN    NaN    NaN    NaN
# 1     MD - Ayurveda Medicine    NaN  ...    NaN    NaN    NaN    NaN    NaN
# 2   MS - Otorhinolaryngology    NaN  ...    NaN    NaN    NaN    NaN    NaN
# 3                       BAMS    NaN  ...    NaN    NaN    NaN    NaN    NaN
# 4                        NaN    NaN  ...    NaN    NaN    NaN    NaN    NaN
#
#   qual 10 exp rating        city           Location
# 0     NaN  24    100   Ernakulam           Kakkanad
# 1     NaN  12     98   Bangalore         Whitefield
# 2     NaN   9    NaN   Bangalore    Mathikere - BEL
# 3     NaN  12    NaN   Bangalore  Bannerghatta Road
# 4     NaN  20    100     Chennai       Keelkattalai
#
# [5 rows x 21 columns]

# %%
df.isnull().sum()/len(df)
# Out:
# Qualification         0.000000
# Experience            0.000000
# Rating                0.553934
# Place                 0.004194
# Profile               0.000000
# Miscellaneous_Info    0.439524
# Fees                  0.000000
# qual 1                0.000000
# qual 2                0.329139
# qual 3                0.770005
# qual 4                0.936923
# qual 5                0.980037
# qual 6                0.994129
# qual 7                0.997987
# qual 8                0.998993
# qual 9                0.999329
# qual 10               0.999832
# exp                   0.000000
# rating                0.553934
# city                  0.004362
# Location              0.004194
# dtype: float64

# %%
df.shape
# Out:
# (5961, 21)

# %% [markdown]
# # we will impute the missing values of 'Rating' column and drop the 'Miscellaneous_Info' as it has over 40% missing data.

# %%
df.drop('Miscellaneous_Info',inplace=True,axis=1)

# %%
df.columns
# Out:
# Index(['Qualification', 'Experience', 'Rating', 'Place', 'Profile', 'Fees',
#        'qual 1', 'qual 2', 'qual 3', 'qual 4', 'qual 5', 'qual 6', 'qual 7',
#        'qual 8', 'qual 9', 'qual 10', 'exp', 'rating', 'city', 'Location'],
#       dtype='object')

# %%
group=['Profile', 'qual 1', 'qual 2', 'qual 3', 'qual 4', 'qual 5',
       'qual 6', 'qual 7', 'qual 8', 'qual 9', 'qual 10', 'Location', 'exp',
       'rating', 'city']
for m in group:
    print(df.groupby(m)['Fees'].mean())
# Out:
# Profile
# Ayurveda            238.968193
# Dentist             238.199714
# Dermatologists      393.133462
# ENT Specialist      387.321429
# General Medicine    313.908781
# Homeopath           306.499407
# Name: Fees, dtype: float64
# qual 1
# 39 years experience                                       300.000000
# Advanced Certificate Course in Aesthetic Dentistry        100.000000
# Ayurvedic panchkarma                                      400.000000
# B.Ac                                                      400.000000
# B.Sc                                                      272.222222
# BAMS                                                      234.457103
# BDS                                                       236.932947
# BEMS                                                      150.000000
# BHMS                                                      301.500000
# BIMS                                                      500.000000
# BSAM                                                      200.000000
# BSc                                                       150.000000
# BSc - Zoology                                             250.000000
# BUMS                                                      100.000000
# CGO                                                       100.000000
# Certificate in Dental Implants                            200.000000
# Certificate of Oral Implantology                          200.000000
# Certification Course In Diabetes                          600.000000
# Certification in Aesthetic Dentistry                      300.000000
# Certification of Aesthetic Dentistry & Periodontics       100.000000
# Certified In Panchkarma                                   300.000000
# Cochlear Implant Surgery                                  600.000000
# D.H.M                                                     500.000000
# DDV                                                       310.000000
# DDVL                                                      360.000000
# DGO                                                       200.000000
# DHMS (Diploma in Homeopathic Medicine and Surgery)        336.111111
# DM - Cardiology                                           550.000000
# DM - Neurology                                            500.000000
# DNB                                                       350.000000
#                                                              ...
# MRCGP                                                     400.000000
# MRCP (UK)                                                 550.000000
# MRCPCH (UK)                                               100.000000
# MRCPS                                                     100.000000
# MRCS (UK)                                                 175.000000
# MS - Ayurveda                                             307.142857
# MS - Ayurvedic Gynecology & Obstetrics                    400.000000
# MS - ENT                                                  387.746479
# MS - General Surgery                                      225.000000
# MS - Orthopaedics                                         300.000000
# MS - Otorhinolaryngology                                  352.000000
# MS - Psychology                                           450.000000
# MSc                                                       600.000000
# MSc - Endocrinology(UK)                                   500.000000
# Masters Diploma in Acupressure                            300.000000
# Member of the Royal College of Physicians                 250.000000
# PDCC - Pediatric Endocrinology                            100.000000
# PG Diploma in Child Health                                300.000000
# PGD ND                                                    100.000000
# POST GRADUATE IN HOMOEOPATHY                              350.000000
# PhD - Neuropsychology                                     400.000000
# PhD - Orthodontics & Dentofacial Orthopaedics             328.571429
# Post Doctoral Fellowship in Diabetology                   350.000000
# Post Graduate Diploma in Dermotology (PGDD)               250.000000
# Post Graduate Diploma in Diabetic Education               500.000000
# Post Graduate Diploma in Diabetology (PGDD)               100.000000
# Post Graduate Diploma in Healthcare Management(PGDHM)     500.000000
# Post Graduate Diploma in Periodontics and Implantology    150.000000
# Post MD SR AIIMS                                          700.000000
# Training in Facial Aesthetics                             300.000000
# Name: Fees, Length: 151, dtype: float64
# qual 2
#  AFIH                                                                                       316.666667
#  Advance Diploma in Nutrition and Dietetics                                                 300.000000
#  Advanced Certificate in Endodontics and Esthetics                                          100.000000
#  Advanced Course in Cosmetology and Aesthetic Medicine                                      100.000000
#  Advanced Endotontic Course On Root Canal                                                   250.000000
#  Ayurvedic panchkarma                                                                       200.000000
#  B.Sc                                                                                       225.000000
#  BAMS                                                                                       284.000000
#  BDS                                                                                        245.035461
#  BEMS                                                                                       450.000000
#  BHMS                                                                                       408.648649
#  BNYS                                                                                       200.000000
#  BPTh/BPT                                                                                   200.000000
#  BSc - Zoology                                                                              200.000000
#  Basic Life Support (BLS)                                                                   175.000000
#  CCEBDM                                                                                     100.000000
#  CCEDM                                                                                      100.000000
#  CGO                                                                                        345.833333
#  Certificate Course In Therapeutic Yoga                                                     250.000000
#  Certificate Course in Advanced Homoeopathy (C.C.A.H)                                       270.000000
#  Certificate Course in Evidence Based Diabetes Management (CCEBDM)                          400.000000
#  Certificate Course in Positive Psychology                                                  200.000000
#  Certificate Course in Sports and Fitness Nutrition                                         500.000000
#  Certificate Endodontics & Pedodontics                                                      200.000000
#  Certificate in Child Health (CCH)                                                          130.666667
#  Certificate in Cosmetic Dentistry                                                          250.000000
#  Certificate in Cosmetology                                                                 400.000000
#  Certificate in Dental Implantology                                                         100.000000
#  Certificate in Dental Implants                                                             275.000000
#  Certificate in Food and Nutrition                                                          500.000000
#                                                                                                ...
#  Post Graduate Diploma In Yoga                                                              150.000000
#  Post Graduate Diploma in Advanced Implantology                                             500.000000
#  Post Graduate Diploma in Clinical Nutrition & Dietetics                                    300.000000
#  Post Graduate Diploma in Clinical Research (PGDCR)                                         150.000000
#  Post Graduate Diploma in Diabetology (PGDD)                                                295.200000
#  Post Graduate Diploma in Diabetology (PGDD)(Johns Hopkins University School of Medicine    350.000000
#  Post Graduate Diploma in Emergency Services (PGDEMS)                                       221.428571
#  Post Graduate Diploma in Endocrinology                                                     100.000000
#  Post Graduate Diploma in Health                                                            200.000000
#  Post Graduate Diploma in Health Sciences (PGDHSc)                                          300.000000
#  Post Graduate Diploma in Healthcare Management(PGDHM)                                      166.666667
#  Post Graduate Diploma in Holistic Healthcare                                               350.000000
#  Post Graduate Diploma in Hospital & Healthcare Management                                  400.000000
#  Post Graduate Diploma in Maternity and Child Health (PGDMCH)                               350.000000
#  Post Graduate Diploma in Medical Cosmetology (PGDMC)                                       400.000000
#  Post Graduate Diploma in Medicological Systems (PGDMS)                                     300.000000
#  Post Graduate Diploma in Orthodontics                                                      100.000000
#  Post Graduate Diploma in Psychological Counseling                                          150.000000
#  Post Graduate Diploma in Sports Medicine                                                   300.000000
#  Post Graduate in Homeopathy(london)                                                        300.000000
#  Post graduate diploma in Hospital Management                                               100.000000
#  Post-Graduate Certificate in Oral Implantology (PGCOI)                                     250.000000
#  Postgraduate Diploma Clinical Cardiology (PGDCC)                                           340.000000
#  Robert Turner Diabetes Research Training                                                   500.000000
#  Singapore                                                                                  300.000000
#  UK (MRCP UK)                                                                               250.000000
#  Venereology & Leprosy                                                                      403.333333
#  Yoga Instructor's Course                                                                   316.666667
#  certification in smile designing                                                           200.000000
# VD & Leprosy                                                                                600.000000
# Name: Fees, Length: 426, dtype: float64
# qual 3
#  ACLS                                                                   200.000000
#  AFIH                                                                   100.000000
#  Advance Diploma in Nutrition and Dietetics                             500.000000
#  Advanced Certificate Course In Diabetes                                350.000000
#  Advanced Certificate Course in Aesthetic Dentistry                     100.000000
#  Advanced Certificate Course in Dental Implants                         100.000000
#  Advanced Endotontic Course On Root Canal                               200.000000
#  Ayurvedic panchkarma                                                   300.000000
#  B.Sc                                                                   250.000000
#  BDS                                                                    254.166667
#  BEMS                                                                   500.000000
#  BHMS                                                                   258.333333
#  BSAM                                                                   250.000000
#  Basic Life Support (BLS)                                               200.000000
#  CCEBDM                                                                 350.000000
#  CCEDM                                                                  500.000000
#  CCT - Dermatology                                                      600.000000
#  CGO                                                                    163.636364
#  Cert. (Prosthodontics)                                                 200.000000
#  Certificate Course in Advanced Homoeopathy (C.C.A.H)                   250.000000
#  Certificate Course in Evidence Based Diabetes Management (CCEBDM)      250.000000
#  Certificate Course in Gestational Diabetes (CCGDM)                     500.000000
#  Certificate Course in Implantology                                     500.000000
#  Certificate Course in Management of Thyroid Disorder                   800.000000
#  Certificate Course in Panchakarma                                      200.000000
#  Certificate Course of One Year in Dental Implants                      400.000000
#  Certificate Endodontics & Pedodontics                                  100.000000
#  Certificate course in SUJOK Therapy                                    100.000000
#  Certificate in Aesthetic Medicine                                      300.000000
#  Certificate in Child Health (CCH)                                      262.500000
#                                                                            ...
#  Post Graduate Diploma in Clinical Research (PGDCR)                     312.500000
#  Post Graduate Diploma in Counselling & Psychotherapy                   100.000000
#  Post Graduate Diploma in Diabetes                                      100.000000
#  Post Graduate Diploma in Diabetology (PGDD)                            364.705882
#  Post Graduate Diploma in Diabetology (PGDD)(Madras Medical College)    300.000000
#  Post Graduate Diploma in Diabetology (PGDD)(Middlesex University       200.000000
#  Post Graduate Diploma in Diabetology (PGDD)(University of Leicester    300.000000
#  Post Graduate Diploma in Emergency Services (PGDEMS)                   300.000000
#  Post Graduate Diploma in Endocrinology                                 575.000000
#  Post Graduate Diploma in Family Medicine (PGDFM)                       200.000000
#  Post Graduate Diploma in Healthcare Management(PGDHM)                  400.000000
#  Post Graduate Diploma in Hospital & Healthcare Management              700.000000
#  Post Graduate Diploma in Maternity and Child Health (PGDMCH)           400.000000
#  Post Graduate Diploma in Orthodontics                                  325.000000
#  Post Graduate in Clinical Psychology                                   500.000000
#  Post MD SR AIIMS                                                       300.000000
#  Post graduate diploma in Health Management                             200.000000
#  Post-Graduate Certificate in Oral Implantology (PGCOI)                 325.000000
#  Professional Diploma in Clinical Research (PDCR)                       400.000000
#  Professional Implantology Training Course (PITC)                       100.000000
#  SCE Dermatology (RCP                                                   700.000000
#  TFO (USA)                                                              500.000000
#  UK (MRCP UK)                                                           500.000000
#  UK)                                                                    550.000000
#  USA)                                                                   350.000000
#  Venereology & Leprosy                                                  396.486486
#  WHO/IDF/EASD Cambridge Diabetes Training                               500.000000
#  Weight Management Consultant Certificate                               250.000000
#  fellowship in medical cosmetology                                      200.000000
# VD & Leprosy                                                            387.500000
# Name: Fees, Length: 406, dtype: float64
# qual 4
#  AMI Essentials- Applied Workshop for Aesthetic Procedures            500.000000
#  AOC in Aesthetic Dentistry                                           200.000000
#  Advance Fellowship in Laser & Dermatosurgery                         600.000000
#  Advanced Certificate Course In Diabetes                              300.000000
#  Advanced Certificate Course in Dental Implants                       100.000000
#  Advanced Trauma Life Support (ATLS)                                  200.000000
#  BA                                                                   500.000000
#  BAMS                                                                 300.000000
#  BDS                                                                  400.000000
#  Bachelor of Acupuncture                                              500.000000
#  Bachelor of Chiropractic                                             200.000000
#  CCD (Diabetology)                                                    800.000000
#  CCEDM                                                                700.000000
#  CCMTD                                                                500.000000
#  CCST - Diabetes & Endocrinology                                      300.000000
#  CCST - Internal Medicine                                             750.000000
#  CGO                                                                  100.000000
#  CSD                                                                  150.000000
#  CVD                                                                   70.000000
#  Certificate Course In Cosmetic Dermatology & Lasers                  500.000000
#  Certificate Course in Advance Implantology                           400.000000
#  Certificate Course in Evidence Based Diabetes Management (CCEBDM)    300.000000
#  Certificate Course in Gestational Diabetes Mellitus                  350.000000
#  Certificate Course in Management of Thyroid Disorder                 700.000000
#  Certificate Course in Nutrition and Dietetics                        300.000000
#  Certificate Course in Oral Implantology                              500.000000
#  Certificate Course in Panchakarma                                    500.000000
#  Certificate Course in Tuberculosis & Chest Diseases                  500.000000
#  Certificate course in Reiki                                          250.000000
#  Certificate in Botox and Fillers                                     100.000000
#                                                                          ...
#  MSc - Psychotherapy And Counselling                                  500.000000
#  MSc - Yoga                                                           350.000000
#  Masters Diploma in Acupressure                                       300.000000
#  Masters in Emergency Medicine                                        500.000000
#  Masters in Oral Implantology                                         500.000000
#  PDCC - Hand                                                          300.000000
#  PG Diploma In Clinical Cosmetology (PGDCC)                           300.000000
#  PG Diploma in Trichology                                             500.000000
#  PG in Diabetology                                                    400.000000
#  PGDCFS                                                               100.000000
#  PGDMLS                                                               200.000000
#  Ph. D - ENT                                                          500.000000
#  PhD - Homoeopathy                                                    200.000000
#  PhD - Microbiology                                                   200.000000
#  Post Graduate Certificate In Hiv And Std Manegement                  100.000000
#  Post Graduate Course in Diabetology                                  633.333333
#  Post Graduate Diploma In Yoga                                        700.000000
#  Post Graduate Diploma in Clinical Research (PGDCR)                   500.000000
#  Post Graduate Diploma in Diabetology (PGDD)                          375.000000
#  Post Graduate Diploma in Endocrinology                               300.000000
#  Post Graduate Diploma in Hospital & Healthcare Management            250.000000
#  Post-Graduate Certificate in Oral Implantology (PGCOI)               225.000000
#  Training Certificate in Hair Transplant                              100.000000
#  UK (MRCP UK)                                                         200.000000
#  UK)                                                                  275.000000
#  Venereology & Leprosy                                                511.764706
#  Yoga Instructor's Course                                             350.000000
# UK)                                                                   700.000000
# VD & Leprosy                                                          200.000000
# germany                                                               200.000000
# Name: Fees, Length: 212, dtype: float64
# qual 5
#  Advanced Certificate Course In Diabetes                                      100.00
#  Advanced Certification in Clinical Diabetology                               100.00
#  Advanced Course in Cosmetology and Aesthetic Medicine                        500.00
#  Advanced Training Program in Diabetes Care                                   500.00
#  CCDR                                                                         500.00
#  CCST - Diabetes & Endocrinology                                              750.00
#  CSD                                                                           70.00
#  CVD                                                                          100.00
#  Certificate Course in Dental Lasers                                          200.00
#  Certificate Course in Evidence Based Diabetes Management (CCEBDM)            500.00
#  Certificate Course in Gestational Diabetes (CCGDM)                           300.00
#  Certificate Course in Management of Thyroid Disorder                         900.00
#  Certificate Course in Nadi Sutra                                             500.00
#  Certificate Course in Sports and Fitness Nutrition                           300.00
#  Certificate in Aesthetic Medicine                                            500.00
#  Certificate in Clinical Cosmetology                                          500.00
#  Certification in Aesthetic Dentistry                                         200.00
#  Certification in Infectious Diseases                                         800.00
#  Certification in Vital Signs: Understanding What the Body Is Telling Us    200.00
#  Certified Analytical Hypnotherapist                                          500.00
#  Certified BPS Dentist                                                        300.00
#  Certified In Panchkarma                                                      700.00
#  Certified in Hair Transplantation                                            600.00
#  Comprehensive Course in Modern Endodontics                                   100.00
#  D.LITT - Diabetology                                                         100.00
#  D.Y.A                                                                        300.00
#  DDVCPS                                                                       500.00
#  DNB - Dermatology & Venereology                                              500.00
#  DNB - ENT                                                                    600.00
#  DNB - Pediatric Surgery                                                      600.00
#                                                                                ...
#  Fellowship in Skull Base Surgery                                             450.00
#  Implant Externship Program                                                   500.00
#  Integrated Clinical Hypnotherapy                                             100.00
#  Invisalign Training Course                                                   100.00
#  MAMS                                                                         575.00
#  MASLP                                                                        400.00
#  MBA                                                                          350.00
#  MBBS                                                                         481.25
#  MCh - Surgical Oncology                                                      300.00
#  MD - General Medicine                                                        500.00
#  MD - Medicine                                                                300.00
#  MD - Pain Management                                                         100.00
#  MDS - Endodontics                                                            100.00
#  MNAMS (Membership of the National Academy)                                   500.00
#  MNAMS - DERMATOLOGY                                                          700.00
#  MNAMS- Family Medicine                                                       500.00
#  MRCS (UK)                                                                    100.00
#  MS - ENT                                                                     200.00
#  MS - Psychology                                                              150.00
#  Master of Family Medicine                                                    300.00
#  Member of the Royal College of Physicians                                    700.00
#  PG Diploma In Clinical Cosmetology (PGDCC)                                   500.00
#  PG in Diabetology                                                            300.00
#  PGDE (Cosmetic & Esthetic Dentist)                                           350.00
#  PGDFOS                                                                       100.00
#  PhD - Alternative Medicine                                                   100.00
#  Post Graduate Diploma in Diabetology (PGDD)                                  350.00
#  Post Graduate Diploma in Diabetology (PGDD)(Cardiff University               700.00
#  USA)                                                                         800.00
#  Venereology & Leprosy                                                        100.00
# Name: Fees, Length: 95, dtype: float64
# qual 6
#  Advanced Certificate Course In Diabetes                    100
#  CCMTD                                                      100
#  CCT - Endocrinology and Diabetes Mellitus                  100
#  Certificate Course In Cosmetic Dermatology & Lasers        500
#  Certificate Course in Implantology                         200
#  Certificate in Cosmetic Dentistry                          300
#  Certification in Aesthetic Dentistry                       500
#  DDVL                                                       100
#  DORL (ENT)                                                 100
#  DVD                                                        500
#  Diploma In Skin Aesthetics                                 100
#  Diploma in Family Medicine (DFM)                           300
#  Diploma in Journalism                                      100
#  Diploma in Naturopathy & Yogic Science (DNYS)              500
#  Diploma in Physiotherapy                                   500
#  FRCP                                                       750
#  FRCS - General Surgery                                     400
#  Fellow Hair Transplant Surgery                             600
#  Fellow Indian Academy Of Clinical Medicine                 100
#  Fellowship in Head & Neck Surgery                          100
#  Fellowship in Implantology                                 500
#  MBA - Hospital Management                                  200
#  MBBS                                                       300
#  MD - Medicine                                              500
#  MRCGP                                                      300
#  Metabolism                                                 500
#  PG Diploma in Trichology                                   500
#  PhD in Liberal Studies in Diabetology (Trinity College)    500
#  Post Graduate Diploma in Diabetology (PGDD)                450
#  UK (MRCP UK)                                               700
#  USA)                                                       350
# UK)                                                         700
# Name: Fees, dtype: int64
# qual 7
#  ACDMC                                               700
#  Advance Course In Osteoporosis                      100
#  Advanced Certification in Clinical Diabetology      100
#  Certificate in Botox                                500
#  Diploma in Tropical Medicine Health                 800
#  Diploma in Weight Loss                              100
#  FCPS - Oto-Rhino-Laryngology                        100
#  FRCP                                                700
#  Fellowship in Aesthetic Medicine                    500
#  Fellowship in Diabetology                           400
#  Postgraduate Diploma Clinical Cardiology (PGDCC)    300
#  Professional Implantology Training Course (PITC)    300
# Name: Fees, dtype: int64
# qual 8
#  CCMTD                                              700
#  EULAR certificate for Rheumatic Diseases           100
#  Fellowship in Advanced Endoscopic Sinus Surgery    300
#  Post Graduate Diploma in Diabetology (PGDD)        300
#  Post graduate certificate In sports Medicine       100
# Fillers                                             500
# Name: Fees, dtype: int64
# qual 9
#  Clinical Cardiology Certification    100
#  Degree in Dental Implant             300
#  MD - Cardiology                      300
#  Threadlifts                          500
# Name: Fees, dtype: int64
# qual 10
#  Fellowship in Lasers & Cosmetology    300
# Name: Fees, dtype: int64
# Location
# AECS Layout           500.000000
# AS Rao Nagar          315.625000
# Abbigere              100.000000
# Abhiramapuram         300.000000
# Abids                 300.000000
# Adambakkam            207.142857
# Adarsh Nagar          270.000000
# Adugodi               225.000000
# Adyar                 493.243243
# Afzalgunj             500.000000
# Agaram                300.000000
# Akshaya nagar         250.000000
# Alaknanda             350.000000
# Alandur               291.666667
# Aluva                 200.000000
# Alwal                 191.666667
# Alwarpet              478.571429
# Alwarthirunagar       175.000000
# Ambalamukku           175.000000
# Ambattur              140.909091
# Amberpet              300.000000
# Ameerpet              292.307692
# Aminjikarai           312.500000
# Anand Lok             800.000000
# Anand Niketan         500.000000
# Anand Vihar           464.285714
# Andheri               325.000000
# Andheri East          339.534884
# Andheri West          364.714286
# Angamaly              100.000000
#                          ...
# Vikrampuri Colony     225.000000
# Vilankurichi          225.000000
# Vileparle             100.000000
# Vileparle East        350.000000
# Vileparle West        253.488372
# Villivakkam           221.428571
# Virugambakkam         250.000000
# Vishnu Garden          50.000000
# Vivek Vihar           250.000000
# Viveknagar            306.250000
# Vizhinjam             150.000000
# Vyasarpadi            200.000000
# Vyttila               207.692308
# Wadala                225.000000
# Walkeshwar            100.000000
# Washermenpet          250.000000
# West Mambalam         220.000000
# West Marredpally      361.111111
# West Of Chord Road    300.000000
# Whitefield            398.936170
# Wilson Garden         300.000000
# Worli                 415.714286
# Yakutpura             200.000000
# Yamuna Vihar          220.000000
# Yelahanka             329.333333
# Yelahanka New Town    314.285714
# Yellareddyguda        750.000000
# Yeshwanthpur          383.333333
# Yousufguda            337.500000
# e                     250.000000
# Name: Fees, Length: 866, dtype: float64
# exp
# 0     197.931034
# 10    308.095238
# 11    297.743056
# 12    312.544803
# 13    327.438017
# 14    342.111554
# 15    324.400000
# 16    318.279570
# 17    311.452514
# 18    336.304348
# 19    328.247012
# 2     240.579710
# 20    313.333333
# 21    325.129870
# 22    345.782313
# 23    331.932773
# 24    303.917526
# 25    324.756098
# 26    344.225352
# 27    344.285714
# 28    354.512195
# 29    349.253731
# 3     257.747748
# 30    333.823529
# 31    353.636364
# 32    303.153846
# 33    385.483871
# 34    289.253731
# 35    339.038462
# 36    290.217391
#          ...
# 40    278.043478
# 41    246.666667
# 42    210.000000
# 43    232.000000
# 44    230.937500
# 45    170.476190
# 46    220.370370
# 47    295.454545
# 48    109.090909
# 49    246.428571
# 5     292.553191
# 50    366.666667
# 51    254.545455
# 52    350.000000
# 53    166.666667
# 54    240.000000
# 55    133.333333
# 56    200.000000
# 57    100.000000
# 58    100.000000
# 59    200.000000
# 6     299.931193
# 60    100.000000
# 61    100.000000
# 64    100.000000
# 65    100.000000
# 66    100.000000
# 7     291.745833
# 8     307.092199
# 9     299.659443
# Name: Fees, Length: 64, dtype: float64
# rating
# 100    316.564327
# 33     575.000000
# 36     600.000000
# 40     700.000000
# 45     500.000000
# 47     650.000000
# 48     800.000000
# 53     100.000000
# 55     450.000000
# 56     320.000000
# 57     300.000000
# 58     550.000000
# 60     307.142857
# 62     300.000000
# 63     525.000000
# 64     500.000000
# 65     100.000000
# 67     504.166667
# 68     520.000000
# 69     475.000000
# 7      100.000000
# 70     250.000000
# 71     351.111111
# 72     416.666667
# 73     443.750000
# 74     500.000000
# 75     331.250000
# 76     255.555556
# 77     484.375000
# 78     408.333333
# 79     465.384615
# 80     400.000000
# 81     429.166667
# 82     377.391304
# 83     326.190476
# 84     450.000000
# 85     370.370370
# 86     371.428571
# 87     339.285714
# 88     367.073171
# 89     442.738095
# 90     353.030303
# 91     404.166667
# 92     364.090909
# 93     356.422018
# 94     362.173913
# 95     365.842697
# 96     332.500000
# 97     346.058091
# 98     314.758621
# 99     317.374517
# Name: Fees, dtype: float64
# city
#  Bangalore             328.842607
#  Chennai               283.602339
#  Coimbatore            154.298246
#  Delhi                 363.006757
#  Ernakulam             188.431373
#  Hyderabad             307.507886
#  Mumbai                308.292863
#  Sector 5              250.000000
#  Thiruvananthapuram    167.267442
# Name: Fees, dtype: float64

# %%
for m in group:
    (pd.DataFrame(df.groupby(m)['Fees'].mean())).plot.bar()

# %%
from sklearn.impute import SimpleImputer

# %%
si=SimpleImputer(strategy='mean')
sim=SimpleImputer(strategy='most_frequent')

# %%
df.isnull().sum()
# Out:
# Qualification       0
# Experience          0
# Rating           3302
# Place              25
# Profile             0
# Fees                0
# qual 1              0
# qual 2           1962
# qual 3           4590
# qual 4           5585
# qual 5           5842
# qual 6           5926
# qual 7           5949
# qual 8           5955
# qual 9           5957
# qual 10          5960
# exp                 0
# rating           3302
# city               26
# Location           25
# dtype: int64

# %%
df['rating']=si.fit_transform(df['rating'].values.reshape(-1,1))
df['Place']=sim.fit_transform(df['Place'].values.reshape(-1,1))
df['Location']=sim.fit_transform(df['Location'].values.reshape(-1,1))

# %%
df.isnull().sum()
# Out:
# Qualification       0
# Experience          0
# Rating           3302
# Place               0
# Profile             0
# Fees                0
# qual 1              0
# qual 2           1962
# qual 3           4590
# qual 4           5585
# qual 5           5842
# qual 6           5926
# qual 7           5949
# qual 8           5955
# qual 9           5957
# qual 10          5960
# exp                 0
# rating              0
# city               26
# Location            0
# dtype: int64

# %%
df.fillna('na',inplace=True)

# %%
df.isnull().sum()
# Out:
# Qualification    0
# Experience       0
# Rating           0
# Place            0
# Profile          0
# Fees             0
# qual 1           0
# qual 2           0
# qual 3           0
# qual 4           0
# qual 5           0
# qual 6           0
# qual 7           0
# qual 8           0
# qual 9           0
# qual 10          0
# exp              0
# rating           0
# city             0
# Location         0
# dtype: int64

# %%
df.head()
# Out:
#                     Qualification           Experience Rating  \
# 0           BHMS, MD - Homeopathy  24 years experience   100%
# 1    BAMS, MD - Ayurveda Medicine  12 years experience    98%
# 2  MBBS, MS - Otorhinolaryngology   9 years experience     na
# 3             BSc - Zoology, BAMS  12 years experience     na
# 4                            BAMS  20 years experience   100%
#
#                           Place         Profile  Fees         qual 1  \
# 0           Kakkanad, Ernakulam       Homeopath   100           BHMS
# 1         Whitefield, Bangalore        Ayurveda   350           BAMS
# 2    Mathikere - BEL, Bangalore  ENT Specialist   300           MBBS
# 3  Bannerghatta Road, Bangalore        Ayurveda   250  BSc - Zoology
# 4         Keelkattalai, Chennai        Ayurveda   250           BAMS
#
#                       qual 2 qual 3 qual 4 qual 5 qual 6 qual 7 qual 8 qual 9  \
# 0            MD - Homeopathy     na     na     na     na     na     na     na
# 1     MD - Ayurveda Medicine     na     na     na     na     na     na     na
# 2   MS - Otorhinolaryngology     na     na     na     na     na     na     na
# 3                       BAMS     na     na     na     na     na     na     na
# 4                         na     na     na     na     na     na     na     na
#
#   qual 10 exp      rating        city           Location
# 0      na  24  100.000000   Ernakulam           Kakkanad
# 1      na  12   98.000000   Bangalore         Whitefield
# 2      na   9   94.643475   Bangalore    Mathikere - BEL
# 3      na  12   94.643475   Bangalore  Bannerghatta Road
# 4      na  20  100.000000     Chennai       Keelkattalai

# %%
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing  import StandardScaler

# %%
le=LabelEncoder()
ss=StandardScaler()

# %%
df.columns
# Out:
# Index(['Qualification', 'Experience', 'Rating', 'Place', 'Profile', 'Fees',
#        'qual 1', 'qual 2', 'qual 3', 'qual 4', 'qual 5', 'qual 6', 'qual 7',
#        'qual 8', 'qual 9', 'qual 10', 'exp', 'rating', 'city', 'Location'],
#       dtype='object')

# %%
transform=['Profile','city','Qualification', 'Experience', 'Rating', 'Place','qual 1', 'qual 2', 'qual 3', 'qual 4', 'qual 5', 'qual 6', 'qual 7',
       'qual 8', 'qual 9', 'qual 10','Location']

# %%
for m in transform:
    df[m]=le.fit_transform(df[m].values.reshape(-1,1))

# %%
df['exp']=(df['exp'].astype(int))

# %%
df.dtypes
# Out:
# Qualification      int32
# Experience         int32
# Rating             int32
# Place              int32
# Profile            int32
# Fees               int64
# qual 1             int32
# qual 2             int32
# qual 3             int32
# qual 4             int32
# qual 5             int32
# qual 6             int32
# qual 7             int32
# qual 8             int32
# qual 9             int32
# qual 10            int32
# exp                int32
# rating           float64
# city               int32
# Location           int32
# dtype: object

# %%
drop=['Qualification','Experience','Rating','Place']
df.drop(drop,inplace=True,axis=1)

# %%
df.head()
# Out:
#    Profile  Fees  qual 1  qual 2  qual 3  qual 4  qual 5  qual 6  qual 7  \
# 0        5   100       8     252     406     212      95      32      12
# 1        0   350       5     241     406     212      95      32      12
# 2        3   300      79     334     406     212      95      32      12
# 3        0   250      12       7     406     212      95      32      12
# 4        0   250       5     426     406     212      95      32      12
#
#    qual 8  qual 9  qual 10  exp      rating  city  Location
# 0       6       4        1   24  100.000000     4       296
# 1       6       4        1   12   98.000000     0       855
# 2       6       4        1    9   94.643475     0       452
# 3       6       4        1   12   94.643475     0        68
# 4       6       4        1   20  100.000000     1       335

# %%
#cols=df.columns
#for m in cols:
    df[m]=ss.fit_transform(df[m].values.reshape(-1,1))
# Out:
#   File "<ipython-input-40-182a0c799967>", line 3
#     df[m]=ss.fit_transform(df[m].values.reshape(-1,1))
#     ^
# IndentationError: unexpected indent

# %%
x=df.drop('Fees',axis=1)
y=df.iloc[:,1].values.reshape(-1,1)

# %%
df.corr()
# Out:
#            Profile      Fees    qual 1    qual 2    qual 3    qual 4  \
# Profile   1.000000  0.145226  0.307982 -0.000341 -0.037070  0.007830
# Fees      0.145226  1.000000  0.233285 -0.177216 -0.119550 -0.081214
# qual 1    0.307982  0.233285  1.000000 -0.416106 -0.178181 -0.074177
# qual 2   -0.000341 -0.177216 -0.416106  1.000000  0.238462  0.124929
# qual 3   -0.037070 -0.119550 -0.178181  0.238462  1.000000  0.353533
# qual 4    0.007830 -0.081214 -0.074177  0.124929  0.353533  1.000000
# qual 5   -0.003564 -0.072367 -0.035840  0.073277  0.180338  0.447644
# qual 6   -0.010431 -0.002848 -0.031672  0.033880  0.085843  0.223890
# qual 7   -0.035738 -0.016726 -0.024447  0.037770  0.080217  0.143277
# qual 8   -0.017796 -0.007351 -0.020418  0.035645  0.059099  0.131739
# qual 9   -0.010817  0.008419 -0.015284  0.021772  0.025391  0.110727
# qual 10   0.011266  0.000539 -0.006264  0.024192  0.039684  0.076960
# exp       0.202073  0.002117  0.201556 -0.045597 -0.030725  0.007565
# rating   -0.111018 -0.090106 -0.183467  0.041943  0.012686 -0.025868
# city     -0.017894 -0.041873 -0.024606  0.039903  0.025523 -0.014474
# Location  0.019533 -0.052750  0.000053  0.010913  0.004174  0.045904
#
#             qual 5    qual 6    qual 7    qual 8    qual 9   qual 10  \
# Profile  -0.003564 -0.010431 -0.035738 -0.017796 -0.010817  0.011266
# Fees     -0.072367 -0.002848 -0.016726 -0.007351  0.008419  0.000539
# qual 1   -0.035840 -0.031672 -0.024447 -0.020418 -0.015284 -0.006264
# qual 2    0.073277  0.033880  0.037770  0.035645  0.021772  0.024192
# qual 3    0.180338  0.085843  0.080217  0.059099  0.025391  0.039684
# qual 4    0.447644  0.223890  0.143277  0.131739  0.110727  0.076960
# qual 5    1.000000  0.443537  0.204406  0.129000  0.205193  0.132786
# qual 6    0.443537  1.000000  0.426790  0.304232  0.430628  0.247791
# qual 7    0.204406  0.426790  1.000000  0.682227  0.400514  0.038744
# qual 8    0.129000  0.304232  0.682227  1.000000  0.516432  0.419150
# qual 9    0.205193  0.430628  0.400514  0.516432  1.000000  0.547615
# qual 10   0.132786  0.247791  0.038744  0.419150  0.547615  1.000000
# exp       0.004045  0.001990 -0.009915  0.002119  0.000645 -0.005459
# rating    0.003039 -0.010748  0.016957  0.024018  0.006833 -0.005821
# city      0.004255  0.007424 -0.002223  0.004090 -0.000010  0.011566
# Location  0.028919 -0.004278  0.018359  0.013407  0.015919  0.019043
#
#                exp    rating      city  Location
# Profile   0.202073 -0.111018 -0.017894  0.019533
# Fees      0.002117 -0.090106 -0.041873 -0.052750
# qual 1    0.201556 -0.183467 -0.024606  0.000053
# qual 2   -0.045597  0.041943  0.039903  0.010913
# qual 3   -0.030725  0.012686  0.025523  0.004174
# qual 4    0.007565 -0.025868 -0.014474  0.045904
# qual 5    0.004045  0.003039  0.004255  0.028919
# qual 6    0.001990 -0.010748  0.007424 -0.004278
# qual 7   -0.009915  0.016957 -0.002223  0.018359
# qual 8    0.002119  0.024018  0.004090  0.013407
# qual 9    0.000645  0.006833 -0.000010  0.015919
# qual 10  -0.005459 -0.005821  0.011566  0.019043
# exp       1.000000 -0.177438  0.013826  0.015970
# rating   -0.177438  1.000000  0.024882  0.015654
# city      0.013826  0.024882  1.000000 -0.092067
# Location  0.015970  0.015654 -0.092067  1.000000

# %%
from sklearn.linear_model import LinearRegression
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.ensemble import AdaBoostRegressor
from sklearn.model_selection import train_test_split
from sklearn.model_selection import cross_val_score
from sklearn.metrics import r2_score, mean_squared_error

# %%
xtrain,xtest,ytrain,ytest=train_test_split(x,y)

# %%
lr,dtr,rfr=LinearRegression(),DecisionTreeRegressor(),RandomForestRegressor()

# %%
model=[lr,dtr,rfr]
for m in model:
    for m in model:
        m.fit(xtrain,ytrain)
        print('train score of', m, 'is', m.score(xtrain,ytrain))
        print('test score of', m, 'is', m.score(xtest,ytest))
        print('r2 score of', m, 'is', r2_score(m.predict(xtest),ytest))
        print('rmse of', m, 'is', np.sqrt(mean_squared_error(m.predict(xtest),ytest)))
        print((cross_val_score(m,x,y,cv=10).mean()))
# Out:
# train score of LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False) is 0.09173988170793124
# test score of LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False) is 0.06603575873752332
# r2 score of LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False) is -9.811725290667361
# rmse of LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False) is 189.97036652668396
# 0.07825087489845592
# train score of DecisionTreeRegressor(criterion='mse', max_depth=None, max_features=None,
#                       max_leaf_nodes=None, min_impurity_decrease=0.0,
#                       min_impurity_split=None, min_samples_leaf=1,
#                       min_samples_split=2, min_weight_fraction_leaf=0.0,
#                       presort=False, random_state=None, splitter='best') is 0.9985019154234902
# test score of DecisionTreeRegressor(criterion='mse', max_depth=None, max_features=None,
#                       max_leaf_nodes=None, min_impurity_decrease=0.0,
#                       min_impurity_split=None, min_samples_leaf=1,
#                       min_samples_split=2, min_weight_fraction_leaf=0.0,
#                       presort=False, random_state=None, splitter='best') is -0.4731201385210418
# r2 score of DecisionTreeRegressor(criterion='mse', max_depth=None, max_features=None,
#                       max_leaf_nodes=None, min_impurity_decrease=0.0,
#                       min_impurity_split=None, min_samples_leaf=1,
#                       min_samples_split=2, min_weight_fraction_leaf=0.0,
#                       presort=False, random_state=None, splitter='best') is -0.4491457716351952
# rmse of DecisionTreeRegressor(criterion='mse', max_depth=None, max_features=None,
#                       max_leaf_nodes=None, min_impurity_decrease=0.0,
#                       min_impurity_split=None, min_samples_leaf=1,
#                       min_samples_split=2, min_weight_fraction_leaf=0.0,
#                       presort=False, random_state=None, splitter='best') is 238.58317822285554
# -0.5396293186106776
# train score of RandomForestRegressor(bootstrap=True, criterion='mse', max_depth=None,
#                       max_features='auto', max_leaf_nodes=None,
#                       min_impurity_decrease=0.0, min_impurity_split=None,
#                       min_samples_leaf=1, min_samples_split=2,
#                       min_weight_fraction_leaf=0.0, n_estimators=10,
#                       n_jobs=None, oob_score=False, random_state=None,
#                       verbose=0, warm_start=False) is 0.8416878904721633
# test score of RandomForestRegressor(bootstrap=True, criterion='mse', max_depth=None,
#                       max_features='auto', max_leaf_nodes=None,
#                       min_impurity_decrease=0.0, min_impurity_split=None,
#                       min_samples_leaf=1, min_samples_split=2,
#                       min_weight_fraction_leaf=0.0, n_estimators=10,
#                       n_jobs=None, oob_score=False, random_state=None,
#                       verbose=0, warm_start=False) is 0.09401696525665248
# r2 score of RandomForestRegressor(bootstrap=True, criterion='mse', max_depth=None,
#                       max_features='auto', max_leaf_nodes=None,
#                       min_impurity_decrease=0.0, min_impurity_split=None,
#                       min_samples_leaf=1, min_samples_split=2,
#                       min_weight_fraction_leaf=0.0, n_estimators=10,
#                       n_jobs=None, oob_score=False, random_state=None,
#                       verbose=0, warm_start=False) is -1.5009126366910372
# rmse of RandomForestRegressor(bootstrap=True, criterion='mse', max_depth=None,
#                       max_features='auto', max_leaf_nodes=None,
#                       min_impurity_decrease=0.0, min_impurity_split=None,
#                       min_samples_leaf=1, min_samples_split=2,
#                       min_weight_fraction_leaf=0.0, n_estimators=10,
#                       n_jobs=None, oob_score=False, random_state=None,
#                       verbose=0, warm_start=False) is 187.10300771693068
# 0.11559336190351807
# train score of LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False) is 0.09173988170793124
# test score of LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False) is 0.06603575873752332
# r2 score of LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False) is -9.811725290667361
# rmse of LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False) is 189.97036652668396
# 0.07825087489845592
# train score of DecisionTreeRegressor(criterion='mse', max_depth=None, max_features=None,
#                       max_leaf_nodes=None, min_impurity_decrease=0.0,
#                       min_impurity_split=None, min_samples_leaf=1,
#                       min_samples_split=2, min_weight_fraction_leaf=0.0,
#                       presort=False, random_state=None, splitter='best') is 0.9985019154234902
# test score of DecisionTreeRegressor(criterion='mse', max_depth=None, max_features=None,
#                       max_leaf_nodes=None, min_impurity_decrease=0.0,
#                       min_impurity_split=None, min_samples_leaf=1,
#                       min_samples_split=2, min_weight_fraction_leaf=0.0,
#                       presort=False, random_state=None, splitter='best') is -0.5026933839867906
# r2 score of DecisionTreeRegressor(criterion='mse', max_depth=None, max_features=None,
#                       max_leaf_nodes=None, min_impurity_decrease=0.0,
#                       min_impurity_split=None, min_samples_leaf=1,
#                       min_samples_split=2, min_weight_fraction_leaf=0.0,
#                       presort=False, random_state=None, splitter='best') is -0.4379891552527111
# rmse of DecisionTreeRegressor(criterion='mse', max_depth=None, max_features=None,
#                       max_leaf_nodes=None, min_impurity_decrease=0.0,
#                       min_impurity_split=None, min_samples_leaf=1,
#                       min_samples_split=2, min_weight_fraction_leaf=0.0,
#                       presort=False, random_state=None, splitter='best') is 240.96608598355093
# -0.5240871460815664
# train score of RandomForestRegressor(bootstrap=True, criterion='mse', max_depth=None,
#                       max_features='auto', max_leaf_nodes=None,
#                       min_impurity_decrease=0.0, min_impurity_split=None,
#                       min_samples_leaf=1, min_samples_split=2,
#                       min_weight_fraction_leaf=0.0, n_estimators=10,
#                       n_jobs=None, oob_score=False, random_state=None,
#                       verbose=0, warm_start=False) is 0.8430891245268891
# test score of RandomForestRegressor(bootstrap=True, criterion='mse', max_depth=None,
#                       max_features='auto', max_leaf_nodes=None,
#                       min_impurity_decrease=0.0, min_impurity_split=None,
#                       min_samples_leaf=1, min_samples_split=2,
#                       min_weight_fraction_leaf=0.0, n_estimators=10,
#                       n_jobs=None, oob_score=False, random_state=None,
#                       verbose=0, warm_start=False) is 0.11269050797008996
# r2 score of RandomForestRegressor(bootstrap=True, criterion='mse', max_depth=None,
#                       max_features='auto', max_leaf_nodes=None,
#                       min_impurity_decrease=0.0, min_impurity_split=None,
#                       min_samples_leaf=1, min_samples_split=2,
#                       min_weight_fraction_leaf=0.0, n_estimators=10,
#                       n_jobs=None, oob_score=False, random_state=None,
#                       verbose=0, warm_start=False) is -1.4523799410146547
# rmse of RandomForestRegressor(bootstrap=True, criterion='mse', max_depth=None,
#                       max_features='auto', max_leaf_nodes=None,
#                       min_impurity_decrease=0.0, min_impurity_split=None,
#                       min_samples_leaf=1, min_samples_split=2,
#                       min_weight_fraction_leaf=0.0, n_estimators=10,
#                       n_jobs=None, oob_score=False, random_state=None,
#                       verbose=0, warm_start=False) is 185.16474440611378
# 0.133116699780768
# train score of LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False) is 0.09173988170793124
# test score of LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False) is 0.06603575873752332
# r2 score of LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False) is -9.811725290667361
# rmse of LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False) is 189.97036652668396
# 0.07825087489845592
# train score of DecisionTreeRegressor(criterion='mse', max_depth=None, max_features=None,
#                       max_leaf_nodes=None, min_impurity_decrease=0.0,
#                       min_impurity_split=None, min_samples_leaf=1,
#                       min_samples_split=2, min_weight_fraction_leaf=0.0,
#                       presort=False, random_state=None, splitter='best') is 0.9985019154234902
# test score of DecisionTreeRegressor(criterion='mse', max_depth=None, max_features=None,
#                       max_leaf_nodes=None, min_impurity_decrease=0.0,
#                       min_impurity_split=None, min_samples_leaf=1,
#                       min_samples_split=2, min_weight_fraction_leaf=0.0,
#                       presort=False, random_state=None, splitter='best') is -0.47839672474097056
# r2 score of DecisionTreeRegressor(criterion='mse', max_depth=None, max_features=None,
#                       max_leaf_nodes=None, min_impurity_decrease=0.0,
#                       min_impurity_split=None, min_samples_leaf=1,
#                       min_samples_split=2, min_weight_fraction_leaf=0.0,
#                       presort=False, random_state=None, splitter='best') is -0.4414038857378566
# rmse of DecisionTreeRegressor(criterion='mse', max_depth=None, max_features=None,
#                       max_leaf_nodes=None, min_impurity_decrease=0.0,
#                       min_impurity_split=None, min_samples_leaf=1,
#                       min_samples_split=2, min_weight_fraction_leaf=0.0,
#                       presort=False, random_state=None, splitter='best') is 239.01008821163794
# -0.5244837632876521
# train score of RandomForestRegressor(bootstrap=True, criterion='mse', max_depth=None,
#                       max_features='auto', max_leaf_nodes=None,
#                       min_impurity_decrease=0.0, min_impurity_split=None,
#                       min_samples_leaf=1, min_samples_split=2,
#                       min_weight_fraction_leaf=0.0, n_estimators=10,
#                       n_jobs=None, oob_score=False, random_state=None,
#                       verbose=0, warm_start=False) is 0.8426496989355609
# test score of RandomForestRegressor(bootstrap=True, criterion='mse', max_depth=None,
#                       max_features='auto', max_leaf_nodes=None,
#                       min_impurity_decrease=0.0, min_impurity_split=None,
#                       min_samples_leaf=1, min_samples_split=2,
#                       min_weight_fraction_leaf=0.0, n_estimators=10,
#                       n_jobs=None, oob_score=False, random_state=None,
#                       verbose=0, warm_start=False) is 0.09110237513946406
# r2 score of RandomForestRegressor(bootstrap=True, criterion='mse', max_depth=None,
#                       max_features='auto', max_leaf_nodes=None,
#                       min_impurity_decrease=0.0, min_impurity_split=None,
#                       min_samples_leaf=1, min_samples_split=2,
#                       min_weight_fraction_leaf=0.0, n_estimators=10,
#                       n_jobs=None, oob_score=False, random_state=None,
#                       verbose=0, warm_start=False) is -1.4869555370100742
# rmse of RandomForestRegressor(bootstrap=True, criterion='mse', max_depth=None,
#                       max_features='auto', max_leaf_nodes=None,
#                       min_impurity_decrease=0.0, min_impurity_split=None,
#                       min_samples_leaf=1, min_samples_split=2,
#                       min_weight_fraction_leaf=0.0, n_estimators=10,
#                       n_jobs=None, oob_score=False, random_state=None,
#                       verbose=0, warm_start=False) is 187.40372565171612
# 0.11377003821070572

# %%
coeff=lr.coef_

# %%
coeff=coeff.reshape(15)
coeff.shape
# Out:
# (15,)

# %%
col=x.columns

# %%
col
# Out:
# Index(['Profile', 'qual 1', 'qual 2', 'qual 3', 'qual 4', 'qual 5', 'qual 6',
#        'qual 7', 'qual 8', 'qual 9', 'qual 10', 'exp', 'rating', 'city',
#        'Location'],
#       dtype='object')

# %%
(pd.DataFrame({'coeff':coeff,'col':col})).plot.bar()

# %%
from sklearn.linear_model import Ridge

# %%
rd=Ridge()

# %%
rd.fit(xtrain,ytrain)
# Out:
# Ridge(alpha=1.0, copy_X=True, fit_intercept=True, max_iter=None,
#       normalize=False, random_state=None, solver='auto', tol=0.001)

# %%
rd.score(xtrain,ytrain)
# Out:
# 0.0917265180391661

# %%
df.skew()
# Out:
# Profile      0.108803
# Fees         0.751870
# qual 1       0.068299
# qual 2      -0.611330
# qual 3      -2.237721
# qual 4      -4.947192
# qual 5      -9.457908
# qual 6     -16.972240
# qual 7     -28.300130
# qual 8     -39.194718
# qual 9     -46.967280
# qual 10    -77.207513
# exp          0.991089
# rating      -4.906222
# city         0.081154
# Location     0.121186
# dtype: float64

# %%
df.head()
# Out:
#    Profile  Fees  qual 1  qual 2  qual 3  qual 4  qual 5  qual 6  qual 7  \
# 0        5   100       8     252     406     212      95      32      12
# 1        0   350       5     241     406     212      95      32      12
# 2        3   300      79     334     406     212      95      32      12
# 3        0   250      12       7     406     212      95      32      12
# 4        0   250       5     426     406     212      95      32      12
#
#    qual 8  qual 9  qual 10  exp      rating  city  Location
# 0       6       4        1   24  100.000000     4       296
# 1       6       4        1   12   98.000000     0       855
# 2       6       4        1    9   94.643475     0       452
# 3       6       4        1   12   94.643475     0        68
# 4       6       4        1   20  100.000000     1       335

# %%
import pickle

# %%
rfr.fit(xtrain,ytrain)
# Out:
# RandomForestRegressor(bootstrap=True, criterion='mse', max_depth=None,
#                       max_features='auto', max_leaf_nodes=None,
#                       min_impurity_decrease=0.0, min_impurity_split=None,
#                       min_samples_leaf=1, min_samples_split=2,
#                       min_weight_fraction_leaf=0.0, n_estimators=10,
#                       n_jobs=None, oob_score=False, random_state=None,
#                       verbose=0, warm_start=False)

# %%
rfr.score(xtrain,ytrain)
# Out:
# 0.8488277878661588

# %%
rfr.fit(x,y)
# Out:
# RandomForestRegressor(bootstrap=True, criterion='mse', max_depth=None,
#                       max_features='auto', max_leaf_nodes=None,
#                       min_impurity_decrease=0.0, min_impurity_split=None,
#                       min_samples_leaf=1, min_samples_split=2,
#                       min_weight_fraction_leaf=0.0, n_estimators=10,
#                       n_jobs=None, oob_score=False, random_state=None,
#                       verbose=0, warm_start=False)

# %%
cv=cross_val_score(rfr,x,y,cv=10)

# %%
cv.mean()
# Out:
# 0.12872218686145814

# %%
cv.std()
# Out:
# 0.03521864575766809

# %%
df=pd.read_csv('test1.csv',encoding = 'unicode_escape')

# %%
qual=df['Qualification'].str.split(',')
qualifications=[]
range=np.arange(0,len(qual))
for m in range:
    qualifications.append(len(qual[m]))

# %%
df['qual 1']=df['Qualification'].str.split(',').str[0]
df['qual 2']=df['Qualification'].str.split(',').str[1]
df['qual 3']=df['Qualification'].str.split(',').str[2]
df['qual 4']=df['Qualification'].str.split(',').str[3]
df['qual 5']=df['Qualification'].str.split(',').str[4]
df['qual 6']=df['Qualification'].str.split(',').str[5]
df['qual 7']=df['Qualification'].str.split(',').str[6]
df['qual 8']=df['Qualification'].str.split(',').str[7]
df['qual 9']=df['Qualification'].str.split(',').str[8]
df['qual 10']=df['Qualification'].str.split(',').str[9]
df['qual 11']=df['Qualification'].str.split(',').str[10]
df['qual 12']=df['Qualification'].str.split(',').str[11]
df['qual 13']=df['Qualification'].str.split(',').str[12]
df['qual 14']=df['Qualification'].str.split(',').str[13]
df['qual 15']=df['Qualification'].str.split(',').str[14]
df['qual 16']=df['Qualification'].str.split(',').str[15]
df['qual 17']=df['Qualification'].str.split(',').str[16]

# %%
df['exp']=df['Experience'].str.split(' ').str[0]

# %%
df['rating']=df['Rating'].str.split('%').str[0]

# %%
df['city']=df['Place'].str.split(',').str[1]

# %%
df['Location']=df['Place'].str.split(',').str[0]

# %%
df.drop('Miscellaneous_Info',inplace=True,axis=1)

# %%
from sklearn.impute import SimpleImputer

# %%
si=SimpleImputer(strategy='mean')
sim=SimpleImputer(strategy='most_frequent')

# %%
df['rating']=si.fit_transform(df['rating'].values.reshape(-1,1))
df['Place']=sim.fit_transform(df['Place'].values.reshape(-1,1))
df['Location']=sim.fit_transform(df['Location'].values.reshape(-1,1))

# %%
df.fillna('na',inplace=True)

# %%
drop=['Qualification','Experience','Rating','Place']
df.drop(drop,inplace=True,axis=1)

# %%
col=df.columns

# %%
for m in col:
    df[m]=le.fit_transform(df[m].values.reshape(-1,1))

# %%
df.head()
# Out:
#    Profile  qual 1  qual 2  qual 3  qual 4  qual 5  qual 6  qual 7  qual 8  \
# 0        4      48     243     195      90      35       8       3       2
# 1        3      48      79     195      90      35       8       3       2
# 2        2      48      28     195      90      35       8       3       2
# 3        0       1     243     195      90      35       8       3       2
# 4        1       2     157     195      90      35       8       3       2
#
#    qual 9  ...  qual 12  qual 13  qual 14  qual 15  qual 16  qual 17  exp  \
# 0       2  ...        1        1        1        1        1        1   28
# 1       2  ...        1        1        1        1        1        1   24
# 2       2  ...        1        1        1        1        1        1   34
# 3       2  ...        1        1        1        1        1        1    0
# 4       2  ...        1        1        1        1        1        1    7
#
#    rating  city  Location
# 0      30     6       142
# 1      30     5       577
# 2       8     1       212
# 3      30     3       373
# 4      36     0       231
#
# [5 rows x 22 columns]

# %%
drop=['qual 11','qual 12','qual 13','qual 14','qual 15','qual 16','qual 17']
df.drop(drop,inplace=True,axis=1)

# %%
pred=rfr.predict(df)

# %%
df['Fees']=pred

# %%
df.to_csv('doctor test.csv')

# %%
g=pd.read_csv('doctor test.csv')

# %%
# Out:
#       Unnamed: 0  Profile  qual 1  qual 2  qual 3  qual 4  qual 5  qual 6  \
# 0              0        4      48     243     195      90      35       8
# 1              1        3      48      79     195      90      35       8
# 2              2        2      48      28     195      90      35       8
# 3              3        0       1     243     195      90      35       8
# 4              4        1       2     157     195      90      35       8
# 5              5        1       2     156     195      90      35       8
# 6              6        3      48      79     195      90      35       8
# 7              7        1       2     167     195      90      35       8
# 8              8        0      50       4     192      63      35       8
# 9              9        5       3     243     195      90      35       8
# 10            10        1       2     243     195      90      35       8
# 11            11        4      48      89     195      90      35       8
# 12            12        2      48      27     195      90      35       8
# 13            13        2      48     132     195      90      35       8
# 14            14        3      81     243     195      90      35       8
# 15            15        1       2     243     195      90      35       8
# 16            16        2      48     132     195      90      35       8
# 17            17        3      48      79     159      18      26       8
# 18            18        1       2     157     195      90      35       8
# 19            19        2      48     132     195      90      35       8
# 20            20        5       3      76      61      24      35       8
# 21            21        1       2     243     195      90      35       8
# 22            22        2      48     132     195      90      35       8
# 23            23        4      48     203     195      90      35       8
# 24            24        4      48     243     195      90      35       8
# 25            25        3      48      79     195      90      35       8
# 26            26        1       2     168     195      90      35       8
# 27            27        1       2     174     195      90      35       8
# 28            28        4      48     135     195      90      35       8
# 29            29        3      81     123     195      90      35       8
# ...          ...      ...     ...     ...     ...     ...     ...     ...
# 1957        1957        1      49     203       4      90      35       8
# 1958        1958        3      48     186      74      90      35       8
# 1959        1959        4      48     139     195      90      35       8
# 1960        1960        1       2     164     195      90      35       8
# 1961        1961        5       3     243     195      90      35       8
# 1962        1962        4      48     214     195      90      35       8
# 1963        1963        5       3     243     195      90      35       8
# 1964        1964        1       2     172      20      90      35       8
# 1965        1965        4      48     181     195      90      35       8
# 1966        1966        4      56     229     129      43      35       8
# 1967        1967        1      73     243     195      90      35       8
# 1968        1968        4      48      39     195      90      35       8
# 1969        1969        0       1     129     195      90      35       8
# 1970        1970        1      76     243     195      90      35       8
# 1971        1971        3      48     186     195      90      35       8
# 1972        1972        2      48      64     195      90      35       8
# 1973        1973        2      48      27     195      90      35       8
# 1974        1974        3      48      79     195      90      35       8
# 1975        1975        4      48     243     195      90      35       8
# 1976        1976        3      48     191     195      90      35       8
# 1977        1977        4      48     187      84      41      35       8
# 1978        1978        1       2     158     195      90      35       8
# 1979        1979        1       2     160     195      90      35       8
# 1980        1980        1      72       5     195      90      35       8
# 1981        1981        2      48     133     190      16      33       8
# 1982        1982        0       1      86     195      90      35       8
# 1983        1983        2      52     241     129      90      35       8
# 1984        1984        4      48     153     195      90      35       8
# 1985        1985        1       2     243     195      90      35       8
# 1986        1986        2      48     133     190      90      35       8
#
#       qual 7  qual 8  qual 9  qual 10  exp  rating  city  Location   Fees
# 0          3       2       2        1   28      30     6       142  460.0
# 1          3       2       2        1   24      30     5       577  360.0
# 2          3       2       2        1   34       8     1       212  525.0
# 3          3       2       2        1    0      30     3       373  370.0
# 4          3       2       2        1    7      36     0       231  235.0
# 5          3       2       2        1    5      25     1       552  300.0
# 6          3       2       2        1   15      29     0       134  560.0
# 7          3       2       2        1   56      29     5        31  330.0
# 8          3       2       2        1    2      35     0        48  255.0
# 9          3       2       2        1   38      30     3       323  510.0
# 10         3       2       2        1   33      36     5       133  350.0
# 11         3       2       2        1   27      30     2       139  380.0
# 12         3       2       2        1    2      34     6       250  445.0
# 13         3       2       2        1    4      35     5        55  410.0
# 14         3       2       2        1   33      30     1       293  365.0
# 15         3       2       2        1   33      30     3       341  435.0
# 16         3       2       2        1    7      22     3       527  500.0
# 17         3       2       2        1   20       4     0        50  460.0
# 18         3       2       2        1   52      30     0       352  205.0
# 19         3       2       2        1   25      25     0        58  445.0
# 20         3       2       2        1    2      30     6       104  457.0
# 21         3       2       2        1   22      30     7       244  270.0
# 22         3       2       2        1   55      30     1       568  405.0
# 23         3       2       2        1    4      36     5        62  405.0
# 24         3       2       2        1   37      30     1       273  360.0
# 25         3       2       2        1   19      30     5       204  480.0
# 26         3       2       2        1   14      36     5       135  350.0
# 27         3       2       2        1   55      32     1        98  220.0
# 28         3       2       2        1   17      30     6       345  555.0
# 29         3       2       2        1   33      30     0        63  460.0
# ...      ...     ...     ...      ...  ...     ...   ...       ...    ...
# 1957       3       2       2        1   55      36     5       213  310.0
# 1958       3       2       2        1   34       1     0       330  605.0
# 1959       3       2       2        1   37      30     6       567  395.0
# 1960       3       2       2        1   21      31     5       431  350.0
# 1961       3       2       2        1   11      30     0       309  450.0
# 1962       3       2       2        1    3      36     3       452  565.0
# 1963       3       2       2        1   22      30     5       164  505.0
# 1964       3       2       2        1   55      30     2       446  205.0
# 1965       3       2       2        1   28      23     1        96  380.0
# 1966       3       2       2        1   16      30     1       512  600.0
# 1967       3       2       2        1    4      34     0       583  330.0
# 1968       3       2       2        1   15      32     0       182  505.0
# 1969       3       2       2        1   25      30     6        88  310.0
# 1970       3       2       2        1   54      30     2       508  220.0
# 1971       3       2       2        1   18      30     3       381  445.0
# 1972       3       2       2        1    6      28     5       339  460.0
# 1973       3       2       2        1   33      30     1       552  540.0
# 1974       3       2       2        1   10      30     3       347  485.0
# 1975       3       2       2        1   18      30     3       397  590.0
# 1976       3       2       2        1    2      19     5       333  425.0
# 1977       3       2       2        1   20      30     3       397  610.0
# 1978       3       2       2        1    6      30     6       425  410.0
# 1979       3       2       2        1    8      36     6       424  420.0
# 1980       3       2       2        1    9      34     1       552  300.0
# 1981       3       2       2        1   55      30     3       287  500.0
# 1982       3       2       2        1    1      30     0        58  250.0
# 1983       3       2       2        1   33      30     1        96  555.0
# 1984       3       2       2        1   56      30     1       423  300.0
# 1985       3       2       2        1    3      34     0        26  320.0
# 1986       3       2       2        1   55      30     1       393  535.0
#
# [1987 rows x 17 columns]
