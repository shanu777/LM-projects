# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
df=pd.read_csv('restaurant.csv',encoding='unicode_escape')

# %%
df.head()
# Out:
#                TITLE  RESTAURANT_ID  \
# 0      CASUAL DINING           9438
# 1  CASUAL DINING,BAR          13198
# 2      CASUAL DINING          10915
# 3        QUICK BITES           6346
# 4     DESSERT PARLOR          15387
#
#                                      CUISINES  \
# 0                 Malwani, Goan, North Indian
# 1              Asian, Modern Indian, Japanese
# 2  North Indian, Chinese, Biryani, Hyderabadi
# 3                            Tibetan, Chinese
# 4                                    Desserts
#
#                                      TIME     CITY        LOCALITY RATING  \
# 0  11am  4pm, 7:30pm  11:30pm (Mon-Sun)    Thane  Dombivali East    3.6
# 1                    6pm  11pm (Mon-Sun)  Chennai       Ramapuram    4.2
# 2     11am  3:30pm, 7pm  11pm (Mon-Sun)  Chennai      Saligramam    3.8
# 3                 11:30am  1am (Mon-Sun)   Mumbai     Bandra West    4.1
# 4                    11am  1am (Mon-Sun)   Mumbai     Lower Parel    3.8
#
# ...

# %%
df.dtypes
# Out:
# TITLE            object
# RESTAURANT_ID     int64
# CUISINES         object
# TIME             object
# CITY             object
# LOCALITY         object
# RATING           object
# VOTES            object
# COST              int64
# dtype: object

# %%
df.isnull().sum()
# Out:
# TITLE               0
# RESTAURANT_ID       0
# CUISINES            0
# TIME                0
# CITY              112
# LOCALITY           98
# RATING              2
# VOTES            1204
# COST                0
# dtype: int64

# %%
titles=list(df['TITLE'].str.split(','))

# %%
list_titles=[]
range=np.arange(0,len(titles))
for m in range:
    list_titles.append(len(titles[m]))

# %%
df['Titles']=list_titles

# %%
cuisines=df['CUISINES'].str.split(',')

# %%
list_cuisines=[]
range=np.arange(0,len(cuisines))
for m in range:
    list_cuisines.append(len(cuisines[m]))

# %%
df['Cuisines Offered']=list_cuisines

# %%
df.head()
# Out:
#                TITLE  RESTAURANT_ID  \
# 0      CASUAL DINING           9438
# 1  CASUAL DINING,BAR          13198
# 2      CASUAL DINING          10915
# 3        QUICK BITES           6346
# 4     DESSERT PARLOR          15387
#
#                                      CUISINES  \
# 0                 Malwani, Goan, North Indian
# 1              Asian, Modern Indian, Japanese
# 2  North Indian, Chinese, Biryani, Hyderabadi
# 3                            Tibetan, Chinese
# 4                                    Desserts
#
#                                      TIME     CITY        LOCALITY RATING  \
# 0  11am  4pm, 7:30pm  11:30pm (Mon-Sun)    Thane  Dombivali East    3.6
# 1                    6pm  11pm (Mon-Sun)  Chennai       Ramapuram    4.2
# 2     11am  3:30pm, 7pm  11pm (Mon-Sun)  Chennai      Saligramam    3.8
# 3                 11:30am  1am (Mon-Sun)   Mumbai     Bandra West    4.1
# 4                    11am  1am (Mon-Sun)   Mumbai     Lower Parel    3.8
#
# ...

# %%
df['LOCALITY'].value_counts()
# Out:
# Gachibowli                                                    166
# Indiranagar                                                   138
# Edappally                                                     122
# Kakkanad                                                      121
# HSR                                                           120
# Kukatpally                                                    117
# Madhapur                                                      117
# Marathahalli                                                  116
# Banjara Hills                                                 113
# Jubilee Hills                                                 113
# Whitefield                                                    111
# Fort Kochi                                                    103
# BTM                                                            99
# Jayanagar                                                      96
# ...

# %%
df.head()
# Out:
#                TITLE  RESTAURANT_ID  \
# 0      CASUAL DINING           9438
# 1  CASUAL DINING,BAR          13198
# 2      CASUAL DINING          10915
# 3        QUICK BITES           6346
# 4     DESSERT PARLOR          15387
#
#                                      CUISINES  \
# 0                 Malwani, Goan, North Indian
# 1              Asian, Modern Indian, Japanese
# 2  North Indian, Chinese, Biryani, Hyderabadi
# 3                            Tibetan, Chinese
# 4                                    Desserts
#
#                                      TIME     CITY        LOCALITY RATING  \
# 0  11am  4pm, 7:30pm  11:30pm (Mon-Sun)    Thane  Dombivali East    3.6
# 1                    6pm  11pm (Mon-Sun)  Chennai       Ramapuram    4.2
# 2     11am  3:30pm, 7pm  11pm (Mon-Sun)  Chennai      Saligramam    3.8
# 3                 11:30am  1am (Mon-Sun)   Mumbai     Bandra West    4.1
# 4                    11am  1am (Mon-Sun)   Mumbai     Lower Parel    3.8
#
# ...

# %%
df['opening time']=(df['TIME'].str.split('').str[0])

# %%
df.head()
# Out:
#                TITLE  RESTAURANT_ID  \
# 0      CASUAL DINING           9438
# 1  CASUAL DINING,BAR          13198
# 2      CASUAL DINING          10915
# 3        QUICK BITES           6346
# 4     DESSERT PARLOR          15387
#
#                                      CUISINES  \
# 0                 Malwani, Goan, North Indian
# 1              Asian, Modern Indian, Japanese
# 2  North Indian, Chinese, Biryani, Hyderabadi
# 3                            Tibetan, Chinese
# 4                                    Desserts
#
#                                      TIME     CITY        LOCALITY RATING  \
# 0  11am  4pm, 7:30pm  11:30pm (Mon-Sun)    Thane  Dombivali East    3.6
# 1                    6pm  11pm (Mon-Sun)  Chennai       Ramapuram    4.2
# 2     11am  3:30pm, 7pm  11pm (Mon-Sun)  Chennai      Saligramam    3.8
# 3                 11:30am  1am (Mon-Sun)   Mumbai     Bandra West    4.1
# 4                    11am  1am (Mon-Sun)   Mumbai     Lower Parel    3.8
#
# ...

# %%
df['closed']=df['opening time'].str.contains('Closed')

# %%
df['closed'].value_counts()
# Out:
# False    12451
# True       239
# Name: closed, dtype: int64

# %%
df['opening time']=df['opening time'].str.split(',')

# %%
df['TIME']=df['TIME'].str.replace('','')

# %%
df.head()
# Out:
#                TITLE  RESTAURANT_ID  \
# 0      CASUAL DINING           9438
# 1  CASUAL DINING,BAR          13198
# 2      CASUAL DINING          10915
# 3        QUICK BITES           6346
# 4     DESSERT PARLOR          15387
#
#                                      CUISINES  \
# 0                 Malwani, Goan, North Indian
# 1              Asian, Modern Indian, Japanese
# 2  North Indian, Chinese, Biryani, Hyderabadi
# 3                            Tibetan, Chinese
# 4                                    Desserts
#
#                                    TIME     CITY        LOCALITY RATING  \
# 0  11am  4pm, 7:30pm  11:30pm (Mon-Sun)    Thane  Dombivali East    3.6
# 1                   6pm  11pm (Mon-Sun)  Chennai       Ramapuram    4.2
# 2     11am  3:30pm, 7pm  11pm (Mon-Sun)  Chennai      Saligramam    3.8
# 3                11:30am  1am (Mon-Sun)   Mumbai     Bandra West    4.1
# 4                   11am  1am (Mon-Sun)   Mumbai     Lower Parel    3.8
#
# ...

# %%
time=df['TIME'].str.split(' ')

# %%
time[0]
# Out:
# ['11am', '', '4pm,', '7:30pm', '', '11:30pm', '(Mon-Sun)']

# %%
test_list=[]
ra=np.arange(0,26)
alpha = 'a'
for i in ra: 
    test_list.append(alpha) 
    alpha = chr(ord(alpha) + 1)

# %%
for m in test_list:
    time=df['TIME'].str.split(m)

# %%
df.head()
# Out:
#                TITLE  RESTAURANT_ID  \
# 0      CASUAL DINING           9438
# 1  CASUAL DINING,BAR          13198
# 2      CASUAL DINING          10915
# 3        QUICK BITES           6346
# 4     DESSERT PARLOR          15387
#
#                                      CUISINES  \
# 0                 Malwani, Goan, North Indian
# 1              Asian, Modern Indian, Japanese
# 2  North Indian, Chinese, Biryani, Hyderabadi
# 3                            Tibetan, Chinese
# 4                                    Desserts
#
#                                    TIME     CITY        LOCALITY RATING  \
# 0  11am  4pm, 7:30pm  11:30pm (Mon-Sun)    Thane  Dombivali East    3.6
# 1                   6pm  11pm (Mon-Sun)  Chennai       Ramapuram    4.2
# 2     11am  3:30pm, 7pm  11pm (Mon-Sun)  Chennai      Saligramam    3.8
# 3                11:30am  1am (Mon-Sun)   Mumbai     Bandra West    4.1
# 4                   11am  1am (Mon-Sun)   Mumbai     Lower Parel    3.8
#
# ...

# %%
drop=['TIME','opening time','RESTAURANT_ID']

# %%
df.drop(drop,inplace=True,axis=1)

# %%
df.head()
# Out:
#                TITLE                                    CUISINES     CITY  \
# 0      CASUAL DINING                 Malwani, Goan, North Indian    Thane
# 1  CASUAL DINING,BAR              Asian, Modern Indian, Japanese  Chennai
# 2      CASUAL DINING  North Indian, Chinese, Biryani, Hyderabadi  Chennai
# 3        QUICK BITES                            Tibetan, Chinese   Mumbai
# 4     DESSERT PARLOR                                    Desserts   Mumbai
#
#          LOCALITY RATING      VOTES  COST  Titles  Cuisines Offered  closed
# 0  Dombivali East    3.6   49 votes  1200       1                 3   False
# 1       Ramapuram    4.2   30 votes  1500       2                 3   False
# 2      Saligramam    3.8  221 votes   800       1                 4   False
# 3     Bandra West    4.1   24 votes   800       1                 2   False
# 4     Lower Parel    3.8  165 votes   300       1                 1   False

# %%
df['title1']=df['TITLE'].str.split(',').str[0]
df['title2']=df['TITLE'].str.split(',').str[1]

# %%
df['c1']=df['CUISINES'].str.split(',').str[0]
df['c2']=df['CUISINES'].str.split(',').str[1]
df['c3']=df['CUISINES'].str.split(',').str[2]
df['c4']=df['CUISINES'].str.split(',').str[3]
df['c5']=df['CUISINES'].str.split(',').str[4]
df['c6']=df['CUISINES'].str.split(',').str[5]
df['c7']=df['CUISINES'].str.split(',').str[6]
df['c8']=df['CUISINES'].str.split(',').str[7]

# %%
df.head()
# Out:
#                TITLE                                    CUISINES     CITY  \
# 0      CASUAL DINING                 Malwani, Goan, North Indian    Thane
# 1  CASUAL DINING,BAR              Asian, Modern Indian, Japanese  Chennai
# 2      CASUAL DINING  North Indian, Chinese, Biryani, Hyderabadi  Chennai
# 3        QUICK BITES                            Tibetan, Chinese   Mumbai
# 4     DESSERT PARLOR                                    Desserts   Mumbai
#
#          LOCALITY RATING      VOTES  COST  Titles  Cuisines Offered  closed  \
# 0  Dombivali East    3.6   49 votes  1200       1                 3   False
# 1       Ramapuram    4.2   30 votes  1500       2                 3   False
# 2      Saligramam    3.8  221 votes   800       1                 4   False
# 3     Bandra West    4.1   24 votes   800       1                 2   False
# 4     Lower Parel    3.8  165 votes   300       1                 1   False
#
# ...

# %%
df.dtypes
# Out:
# TITLE               object
# CUISINES            object
# CITY                object
# LOCALITY            object
# RATING              object
# VOTES               object
# COST                 int64
# Titles               int64
# Cuisines Offered     int64
# closed                bool
# title1              object
# title2              object
# c1                  object
# c2                  object
# c3                  object
# c4                  object
# c5                  object
# c6                  object
# c7                  object
# c8                  object
# dtype: object

# %%
df.columns
# Out:
# Index(['TITLE', 'CUISINES', 'CITY', 'LOCALITY', 'RATING', 'VOTES', 'COST',
#        'Titles', 'Cuisines Offered', 'closed', 'title1', 'title2', 'c1', 'c2',
#        'c3', 'c4', 'c5', 'c6', 'c7', 'c8'],
#       dtype='object')

# %%
col=['TITLE', 'CUISINES', 'CITY', 'LOCALITY', 'RATING', 'VOTES',
       'Titles', 'Cuisines Offered', 'closed', 'title1', 'title2', 'c1', 'c2',
       'c3', 'c4', 'c5', 'c6', 'c7', 'c8']

# %%
for m in col:
    print(pd.DataFrame(df.groupby(m)['COST'].mean()))
# Out:
#                                      COST
# TITLE
# BAKERY                         330.129139
# BAKERY,BEVERAGE SHOP           200.000000
# BAKERY,CAFÉ                    626.923077
# BAKERY,CONFECTIONERY           400.000000
# BAKERY,DESSERT PARLOR          380.392157
# BAKERY,FOOD COURT              200.000000
# BAKERY,QUICK BITES             330.978261
# BAKERY,SWEET SHOP              250.000000
# BAR                           1364.835165
# BAR,CAFÉ                      1250.000000
# BAR,CASUAL DINING             1446.093750
# BAR,CLUB                      1000.000000
# BAR,FINE DINING               2116.666667
# BAR,LOUNGE                    1975.000000
# BAR,MICROBREWERY              2500.000000
# BAR,PUB                       1564.285714
# BEVERAGE SHOP                  235.064103
# BEVERAGE SHOP,CAFÉ             333.333333
# BEVERAGE SHOP,CASUAL DINING    500.000000
# BEVERAGE SHOP,DESSERT PARLOR   319.047619
# BEVERAGE SHOP,FOOD COURT       150.000000
# ...

# %%
for m in col:
    print(pd.DataFrame(df.groupby(m)['COST'].mean()).plot.bar())
# Out:
# AxesSubplot(0.125,0.125;0.775x0.755)
# AxesSubplot(0.125,0.125;0.775x0.755)
# AxesSubplot(0.125,0.125;0.775x0.755)
# AxesSubplot(0.125,0.125;0.775x0.755)
# AxesSubplot(0.125,0.125;0.775x0.755)
# AxesSubplot(0.125,0.125;0.775x0.755)
# AxesSubplot(0.125,0.125;0.775x0.755)
# AxesSubplot(0.125,0.125;0.775x0.755)
# AxesSubplot(0.125,0.125;0.775x0.755)
# AxesSubplot(0.125,0.125;0.775x0.755)
# AxesSubplot(0.125,0.125;0.775x0.755)
# AxesSubplot(0.125,0.125;0.775x0.755)
# AxesSubplot(0.125,0.125;0.775x0.755)
# AxesSubplot(0.125,0.125;0.775x0.755)
# AxesSubplot(0.125,0.125;0.775x0.755)
# AxesSubplot(0.125,0.125;0.775x0.755)
# AxesSubplot(0.125,0.125;0.775x0.755)
# AxesSubplot(0.125,0.125;0.775x0.755)
# AxesSubplot(0.125,0.125;0.775x0.755)

# %%
drop=['TITLE','CUISINES']

# %%
df.drop(drop,inplace=True,axis=1)

# %%
from sklearn.preprocessing import LabelEncoder

# %%
le=LabelEncoder()

# %%
df.isnull().sum()
# Out:
# CITY                  112
# LOCALITY               98
# RATING                  2
# VOTES                1204
# COST                    0
# Titles                  0
# Cuisines Offered        0
# closed                  0
# title1                  0
# title2              11208
# c1                      0
# c2                   3062
# c3                   6999
# c4                   9995
# c5                  11675
# c6                  12276
# c7                  12514
# c8                  12613
# dtype: int64

# %%
df.dtypes
# Out:
# CITY                object
# LOCALITY            object
# RATING              object
# VOTES               object
# COST                 int64
# Titles               int64
# Cuisines Offered     int64
# closed                bool
# title1              object
# title2              object
# c1                  object
# c2                  object
# c3                  object
# c4                  object
# c5                  object
# c6                  object
# c7                  object
# c8                  object
# dtype: object

# %%
df.dtypes
# Out:
# CITY                object
# LOCALITY            object
# RATING              object
# VOTES               object
# COST                 int64
# Titles               int64
# Cuisines Offered     int64
# closed                bool
# title1              object
# title2              object
# c1                  object
# c2                  object
# c3                  object
# c4                  object
# c5                  object
# c6                  object
# c7                  object
# c8                  object
# dtype: object

# %%
df.head()
# Out:
#       CITY        LOCALITY RATING      VOTES  COST  Titles  Cuisines Offered  \
# 0    Thane  Dombivali East    3.6   49 votes  1200       1                 3
# 1  Chennai       Ramapuram    4.2   30 votes  1500       2                 3
# 2  Chennai      Saligramam    3.8  221 votes   800       1                 4
# 3   Mumbai     Bandra West    4.1   24 votes   800       1                 2
# 4   Mumbai     Lower Parel    3.8  165 votes   300       1                 1
#
#    closed          title1 title2            c1              c2             c3  \
# 0   False   CASUAL DINING    NaN       Malwani            Goan   North Indian
# 1   False   CASUAL DINING    BAR         Asian   Modern Indian       Japanese
# 2   False   CASUAL DINING    NaN  North Indian         Chinese        Biryani
# 3   False     QUICK BITES    NaN       Tibetan         Chinese            NaN
# 4   False  DESSERT PARLOR    NaN      Desserts             NaN            NaN
#
# ...

# %%
df['RATING'].replace('NEW',np.nan,inplace=True)

# %%
df['RATING']=df['RATING'].str.join('')

# %%
df['RATING'].replace('-',np.nan,inplace=True)

# %%
df['RATING']=df['RATING'].astype(float)

# %%
df['VOTES']=df['VOTES'].str.split(' ').str[0]

# %%
df.head()
# Out:
#       CITY        LOCALITY  RATING VOTES  COST  Titles  Cuisines Offered  \
# 0    Thane  Dombivali East     3.6    49  1200       1                 3
# 1  Chennai       Ramapuram     4.2    30  1500       2                 3
# 2  Chennai      Saligramam     3.8   221   800       1                 4
# 3   Mumbai     Bandra West     4.1    24   800       1                 2
# 4   Mumbai     Lower Parel     3.8   165   300       1                 1
#
#    closed          title1 title2            c1              c2             c3  \
# 0   False   CASUAL DINING    NaN       Malwani            Goan   North Indian
# 1   False   CASUAL DINING    BAR         Asian   Modern Indian       Japanese
# 2   False   CASUAL DINING    NaN  North Indian         Chinese        Biryani
# 3   False     QUICK BITES    NaN       Tibetan         Chinese            NaN
# 4   False  DESSERT PARLOR    NaN      Desserts             NaN            NaN
#
#             c4   c5   c6   c7   c8
# ...

# %%
df['VOTES']=df['VOTES'].astype(float)

# %%
df.dtypes
# Out:
# CITY                 object
# LOCALITY             object
# RATING              float64
# VOTES               float64
# COST                  int64
# Titles                int64
# Cuisines Offered      int64
# closed                 bool
# title1               object
# title2               object
# c1                   object
# c2                   object
# c3                   object
# c4                   object
# c5                   object
# c6                   object
# c7                   object
# c8                   object
# dtype: object

# %%
df.isnull().sum()
# Out:
# CITY                  112
# LOCALITY               98
# RATING               1202
# VOTES                1204
# COST                    0
# Titles                  0
# Cuisines Offered        0
# closed                  0
# title1                  0
# title2              11208
# c1                      0
# c2                   3062
# c3                   6999
# c4                   9995
# c5                  11675
# c6                  12276
# c7                  12514
# c8                  12613
# dtype: int64

# %%
df.dtypes

# %%
from sklearn.impute import SimpleImputer
si=SimpleImputer(strategy='mean')
df['RATING']=si.fit_transform(df['RATING'].values.reshape(-1,1))

# %%
df['VOTES']=si.fit_transform(df['VOTES'].values.reshape(-1,1))

# %%
sim=SimpleImputer(strategy='most_frequent')

# %%
impute=['LOCALITY','CITY']
for m in impute:
    df[m]=sim.fit_transform(df[m].values.reshape(-1,1))

# %%
df.fillna('na',inplace=True)

# %%
df.isnull().sum()
# Out:
# CITY                0
# LOCALITY            0
# RATING              0
# VOTES               0
# COST                0
# Titles              0
# Cuisines Offered    0
# closed              0
# title1              0
# title2              0
# c1                  0
# c2                  0
# c3                  0
# c4                  0
# c5                  0
# c6                  0
# c7                  0
# c8                  0
# dtype: int64

# %%
df.head()
# Out:
#       CITY        LOCALITY  RATING  VOTES  COST  Titles  Cuisines Offered  \
# 0    Thane  Dombivali East     3.6   49.0  1200       1                 3
# 1  Chennai       Ramapuram     4.2   30.0  1500       2                 3
# 2  Chennai      Saligramam     3.8  221.0   800       1                 4
# 3   Mumbai     Bandra West     4.1   24.0   800       1                 2
# 4   Mumbai     Lower Parel     3.8  165.0   300       1                 1
#
#    closed          title1 title2            c1              c2             c3  \
# 0   False   CASUAL DINING     na       Malwani            Goan   North Indian
# 1   False   CASUAL DINING    BAR         Asian   Modern Indian       Japanese
# 2   False   CASUAL DINING     na  North Indian         Chinese        Biryani
# 3   False     QUICK BITES     na       Tibetan         Chinese             na
# 4   False  DESSERT PARLOR     na      Desserts              na             na
#
#             c4  c5  c6  c7  c8
# ...

# %%
df.dtypes
# Out:
# CITY                 object
# LOCALITY             object
# RATING              float64
# VOTES               float64
# COST                  int64
# Titles                int64
# Cuisines Offered      int64
# closed                 bool
# title1               object
# title2               object
# c1                   object
# c2                   object
# c3                   object
# c4                   object
# c5                   object
# c6                   object
# c7                   object
# c8                   object
# dtype: object

# %%
le=LabelEncoder()

# %%
df.columns
# Out:
# Index(['CITY', 'LOCALITY', 'RATING', 'VOTES', 'COST', 'Titles',
#        'Cuisines Offered', 'closed', 'title1', 'title2', 'c1', 'c2', 'c3',
#        'c4', 'c5', 'c6', 'c7', 'c8'],
#       dtype='object')

# %%
col=['CITY', 'LOCALITY','title1', 'title2', 'c1', 'c2', 'c3',
       'c4', 'c5', 'c6', 'c7', 'c8']

# %%
for m in col:
    df[m]=le.fit_transform(df[m].values.reshape(-1,1))

# %%
from sklearn.linear_model import LinearRegression
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.ensemble import AdaBoostRegressor
from sklearn.model_selection import cross_val_score
from sklearn.metrics import r2_score,mean_squared_error

# %%
lr,dtr,rfr=LinearRegression(),DecisionTreeRegressor(),RandomForestRegressor()

# %%
model=[lr,dtr,rfr]

# %%
x=df.drop('COST',axis=1)

# %%
y=df.iloc[:,4]

# %%
for m in model:
    m.fit(x,y)
    print(m.score(x,y))
    cv=cross_val_score(m,x,y,cv=10)
    print(cv.mean())
# Out:
# 0.22399659895146606
# 0.22384198851636902
# 0.9997840921252309
# 0.43368409136381175
# 0.9434034699084726
# 0.6749341495870762

# %%
rfr.fit(x,y)
# Out:
# RandomForestRegressor(bootstrap=True, criterion='mse', max_depth=None,
#                       max_features='auto', max_leaf_nodes=None,
#                       min_impurity_decrease=0.0, min_impurity_split=None,
#                       min_samples_leaf=1, min_samples_split=2,
#                       min_weight_fraction_leaf=0.0, n_estimators=10,
#                       n_jobs=None, oob_score=False, random_state=None,
#                       verbose=0, warm_start=False)
