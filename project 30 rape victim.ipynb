# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv('rape.csv')

# %%
df.head()
# Out:
#                    Area_Name  Year                Subgroup  \
# 0  Andaman & Nicobar Islands  2001      Total Rape Victims
# 1  Andaman & Nicobar Islands  2001  Victims of Incest Rape
# 2  Andaman & Nicobar Islands  2001   Victims of Other Rape
# 3  Andaman & Nicobar Islands  2002      Total Rape Victims
# 4  Andaman & Nicobar Islands  2002  Victims of Incest Rape
#
#    Rape_Cases_Reported  Victims_Above_50_Yrs  Victims_Between_10-14_Yrs  \
# 0                    3                     0                          0
# 1                    1                     0                          0
# 2                    2                     0                          0
# 3                    2                     0                          0
# 4                    0                     0                          0
#
#    Victims_Between_14-18_Yrs  Victims_Between_18-30_Yrs  \
# 0                          3                          0
# 1                          1                          0
# ...

# %%
df.isnull().sum()
# Out:
# Area_Name                    0
# Year                         0
# Subgroup                     0
# Rape_Cases_Reported          0
# Victims_Above_50_Yrs         0
# Victims_Between_10-14_Yrs    0
# Victims_Between_14-18_Yrs    0
# Victims_Between_18-30_Yrs    0
# Victims_Between_30-50_Yrs    0
# Victims_of_Rape_Total        0
# Victims_Upto_10_Yrs          0
# dtype: int64

# %%
df.drop('Victims_of_Rape_Total',inplace=True,axis=1)

# %%
cases_per_year=df.groupby('Year')['Rape_Cases_Reported'].mean()

# %%
plt.plot(cases_per_year)

# %% [markdown]
# #By looking at the above graph it can be said that the cases of the rapes have been increasing with year.

# %%
df.describe()
# Out:
#              Year  Rape_Cases_Reported  Victims_Above_50_Yrs  \
# count  1050.00000          1050.000000           1050.000000
# mean   2005.50000           361.920000              1.866667
# std       2.87365           592.180572              4.640286
# min    2001.00000             0.000000              0.000000
# 25%    2003.00000             4.000000              0.000000
# 50%    2005.50000            37.000000              0.000000
# 75%    2008.00000           527.500000              1.000000
# max    2010.00000          3135.000000             43.000000
#
#        Victims_Between_10-14_Yrs  Victims_Between_14-18_Yrs  \
# count                1050.000000                1050.000000
# mean                   23.657143                  53.085714
# std                    50.677418                 115.127899
# min                     0.000000                   0.000000
# 25%                     0.000000                   0.000000
# ...

# %%
df.sum()
# Out:
# Area_Name                    Andaman & Nicobar IslandsAndaman & Nicobar Isl...
# Year                                                                   2105775
# Subgroup                     Total Rape VictimsVictims of Incest RapeVictim...
# Rape_Cases_Reported                                                     380016
# Victims_Above_50_Yrs                                                      1960
# Victims_Between_10-14_Yrs                                                24840
# Victims_Between_14-18_Yrs                                                55740
# Victims_Between_18-30_Yrs                                               223584
# Victims_Between_30-50_Yrs                                                63248
# Victims_Upto_10_Yrs                                                      10936
# dtype: object

# %%
223584/380016
# Out:
# 0.5883541745610711

# %% [markdown]
# #it can be inferred that the most vulnerable age group is between 18-30 years old, as it has the highest overall mean and also the maximum cases reported is 1835 in a year.The total cases reported is also the highest for this age group at 223584 which is 58.83% of all the rape cases reported.
# Second most vulenarable age group being age 30 to 50.

# %%
df.sort_values('Rape_Cases_Reported',ascending=False)
# Out:
#                  Area_Name  Year                Subgroup  Rape_Cases_Reported  \
# 597         Madhya Pradesh  2010      Total Rape Victims                 3135
# 599         Madhya Pradesh  2010   Victims of Other Rape                 3114
# 588         Madhya Pradesh  2007      Total Rape Victims                 3010
# 594         Madhya Pradesh  2009      Total Rape Victims                 2998
# 596         Madhya Pradesh  2009   Victims of Other Rape                 2984
# 590         Madhya Pradesh  2007   Victims of Other Rape                 2961
# 591         Madhya Pradesh  2008      Total Rape Victims                 2937
# 582         Madhya Pradesh  2005      Total Rape Victims                 2921
# 585         Madhya Pradesh  2006      Total Rape Victims                 2900
# 573         Madhya Pradesh  2002      Total Rape Victims                 2891
# 593         Madhya Pradesh  2008   Victims of Other Rape                 2885
# ...

# %%
#Madhya Pradesh has the highest number of cases reported every year, followed by West Bengol and UP.

# %%
plt.rcParams['figure.figsize']=(50,30)
x=df.Area_Name
y=df.Rape_Cases_Reported
plt.bar(x,y)
# Out:
# <BarContainer object of 1050 artists>

# %%
df['children']=df['Victims_Between_10-14_Yrs']+df['Victims_Between_14-18_Yrs']+df['Victims_Upto_10_Yrs']

# %%
df.head()
# Out:
#                    Area_Name  Year                Subgroup  \
# 0  Andaman & Nicobar Islands  2001      Total Rape Victims
# 1  Andaman & Nicobar Islands  2001  Victims of Incest Rape
# 2  Andaman & Nicobar Islands  2001   Victims of Other Rape
# 3  Andaman & Nicobar Islands  2002      Total Rape Victims
# 4  Andaman & Nicobar Islands  2002  Victims of Incest Rape
#
#    Rape_Cases_Reported  Victims_Above_50_Yrs  Victims_Between_10-14_Yrs  \
# 0                    3                     0                          0
# 1                    1                     0                          0
# 2                    2                     0                          0
# 3                    2                     0                          0
# 4                    0                     0                          0
#
#    Victims_Between_14-18_Yrs  Victims_Between_18-30_Yrs  \
# 0                          3                          0
# 1                          1                          0
# ...

# %%
max_cases=df[df['Rape_Cases_Reported']==3135]

# %%
max_cases
# Out:
#           Area_Name  Year            Subgroup  Rape_Cases_Reported  \
# 597  Madhya Pradesh  2010  Total Rape Victims                 3135
#
#      Victims_Above_50_Yrs  Victims_Between_10-14_Yrs  \
# 597                    12                        304
#
#      Victims_Between_14-18_Yrs  Victims_Between_18-30_Yrs  \
# 597                        826                       1364
#
#      Victims_Between_30-50_Yrs  Victims_Upto_10_Yrs
# 597                        577                   53

# %%
df.describe()
# Out:
#              Year  Rape_Cases_Reported  Victims_Above_50_Yrs  \
# count  1050.00000          1050.000000           1050.000000
# mean   2005.50000           361.920000              1.866667
# std       2.87365           592.180572              4.640286
# min    2001.00000             0.000000              0.000000
# 25%    2003.00000             4.000000              0.000000
# 50%    2005.50000            37.000000              0.000000
# 75%    2008.00000           527.500000              1.000000
# max    2010.00000          3135.000000             43.000000
#
#        Victims_Between_10-14_Yrs  Victims_Between_14-18_Yrs  \
# count                1050.000000                1050.000000
# mean                   23.657143                  53.085714
# std                    50.677418                 115.127899
# min                     0.000000                   0.000000
# 25%                     0.000000                   0.000000
# ...

# %%
most_children_victim=df[df['children']==1183]

# %%
most_children_victim
# Out:
#           Area_Name  Year            Subgroup  Rape_Cases_Reported  \
# 597  Madhya Pradesh  2010  Total Rape Victims                 3135
#
#      Victims_Above_50_Yrs  Victims_Between_10-14_Yrs  \
# 597                    12                        304
#
#      Victims_Between_14-18_Yrs  Victims_Between_18-30_Yrs  \
# 597                        826                       1364
#
#      Victims_Between_30-50_Yrs  Victims_Upto_10_Yrs  children
# 597                        577                   53      1183

# %%
state_crime_rate=pd.DataFrame(df.groupby('Area_Name')['children'].sum())

# %%
state_crime_rate.sort_values('children',ascending=False)
# Out:
#                            children
# Area_Name
# Madhya Pradesh                17522
# Maharashtra                   12794
# Uttar Pradesh                  9758
# Andhra Pradesh                 7392
# Chhattisgarh                   6990
# Delhi                          5664
# Rajasthan                      5306
# Kerala                         3636
# Tamil Nadu                     2818
# Haryana                        2256
# Punjab                         2092
# Gujarat                        1942
# Karnataka                      1776
# Odisha                         1742
# Bihar                          1266
# Assam                          1216
# Himachal Pradesh               1164
# West Bengal                     984
# Tripura                         926
# Meghalaya                       864
# Jharkhand                       856
# Mizoram                         484
# Goa                             358
# Uttarakhand                     298
# Chandigarh                      258
# ...

# %% [markdown]
# #from above analysis it is clear that mp is the most unsafe place according to the data, as it has most number of cases in every aspect.
